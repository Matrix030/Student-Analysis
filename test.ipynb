# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/test_data.csv', header=0)

# %%
df
# Out:
#                           Timestamp  Applied Mathematics - III  \
# 0    2021/09/27 3:17:41 pm GMT+5:30                         94
# 1    2021/09/27 3:18:59 pm GMT+5:30                         90
# 2    2021/09/27 3:21:14 pm GMT+5:30                         19
# 3    2021/09/27 3:22:52 pm GMT+5:30                         71
# 4    2021/09/27 3:24:11 pm GMT+5:30                         64
# ..                              ...                        ...
# 110  2021/09/27 6:33:17 pm GMT+5:30                         39
# 111  2021/09/27 6:34:25 pm GMT+5:30                         30
# 112  2021/09/27 6:35:25 pm GMT+5:30                         55
# 113  2021/09/27 6:36:49 pm GMT+5:30                         31
# 114  2021/09/27 6:37:59 pm GMT+5:30                         47
#
#      Applied Mathematics - IV  Discrete Structure and Graph Theory  \
# 0                          93                                   82
# 1                          79                                   64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Timestamp                                 115 non-null    object
#  1   Applied Mathematics - III                 115 non-null    int64
#  2   Applied Mathematics - IV                  115 non-null    int64
#  3   Discrete Structure and Graph Theory       115 non-null    int64
#  4   Data Structures                           115 non-null    int64
#  5   Analysis Of Algorithm                     115 non-null    int64
#  6   Skill Based Lab (Java)                    115 non-null    int64
#  7   Skill Based Lab (Python)                  115 non-null    int64
#  8   SEM III Project Marks                     0 non-null      float64
#  9   SEM IV Project Marks                      0 non-null      float64
# ...

# %%
df.head()
# Out:
#                         Timestamp  Applied Mathematics - III  \
# 0  2021/09/27 3:17:41 pm GMT+5:30                         94
# 1  2021/09/27 3:18:59 pm GMT+5:30                         90
# 2  2021/09/27 3:21:14 pm GMT+5:30                         19
# 3  2021/09/27 3:22:52 pm GMT+5:30                         71
# 4  2021/09/27 3:24:11 pm GMT+5:30                         64
#
#    Applied Mathematics - IV  Discrete Structure and Graph Theory  \
# 0                        93                                   82
# 1                        79                                   64
# 2                        71                                   48
# 3                        69                                   62
# 4                        80                                   62
#
#    Data Structures  Analysis Of Algorithm  Skill Based Lab (Java)  \
# 0               70                     86                      47
# 1               80                     70                      46
# ...

# %%
df.shape
# Out:
# (115, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                           Timestamp  Applied Mathematics - III  \
# 0    2021/09/27 3:17:41 pm GMT+5:30                         94
# 1    2021/09/27 3:18:59 pm GMT+5:30                         90
# 2    2021/09/27 3:21:14 pm GMT+5:30                         19
# 3    2021/09/27 3:22:52 pm GMT+5:30                         71
# 4    2021/09/27 3:24:11 pm GMT+5:30                         64
# ..                              ...                        ...
# 110  2021/09/27 6:33:17 pm GMT+5:30                         39
# 111  2021/09/27 6:34:25 pm GMT+5:30                         30
# 112  2021/09/27 6:35:25 pm GMT+5:30                         55
# 113  2021/09/27 6:36:49 pm GMT+5:30                         31
# 114  2021/09/27 6:37:59 pm GMT+5:30                         47
#
#      Applied Mathematics - IV  Discrete Structure and Graph Theory  \
# 0                          93                                   82
# ...

# %%
df.corr()
# Out:
#                                           Applied Mathematics - III  \
# Applied Mathematics - III                                  1.000000
# Applied Mathematics - IV                                   0.783799
# Discrete Structure and Graph Theory                        0.677680
# Data Structures                                            0.660466
# Analysis Of Algorithm                                      0.687216
# Skill Based Lab (Java)                                     0.027807
# Skill Based Lab (Python)                                   0.262948
# SEM III Project Marks                                           NaN
# SEM IV Project Marks                                            NaN
# Member of any Student Chapter                                   NaN
# GPA_SEM_III                                                0.695409
# GP_SEM_IV                                                  0.586120
# Number of Internships Completed/ Ongoing                        NaN
# ...

# %%
del df['SEM III Project Marks']
del df['SEM IV Project Marks']
del df['Number of Internships Completed/ Ongoing']
del df['Attendance']
del df['Member of any Student Chapter']
del df['Timestamp']

# %%
df.head(10)
# Out:
#    Applied Mathematics - III  Applied Mathematics - IV  \
# 0                         94                        93
# 1                         90                        79
# 2                         19                        71
# 3                         71                        69
# 4                         64                        80
# 5                         67                        70
# 6                         96                        94
# 7                         90                        92
# 8                         83                        81
# 9                         26                        58
#
#    Discrete Structure and Graph Theory  Data Structures  \
# 0                                   82               70
# 1                                   64               80
# 2                                   48               40
# 3                                   62               54
# 4                                   62               43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Applied Mathematics - III            115 non-null    int64
#  1   Applied Mathematics - IV             115 non-null    int64
#  2   Discrete Structure and Graph Theory  115 non-null    int64
#  3   Data Structures                      115 non-null    int64
#  4   Analysis Of Algorithm                115 non-null    int64
#  5   Skill Based Lab (Java)               115 non-null    int64
#  6   Skill Based Lab (Python)             115 non-null    int64
#  7   GPA_SEM_III                          115 non-null    float64
#  8   GP_SEM_IV                            115 non-null    float64
# dtypes: float64(2), int64(7)
# memory usage: 8.2 KB

# %%
df['avg_GPA'] = (df.GPA_SEM_III +df.GP_SEM_IV)/2

# %%
df.describe()
# Out:
#        Applied Mathematics - III  Applied Mathematics - IV  \
# count                 115.000000                115.000000
# mean                   66.843478                 72.260870
# std                    18.808635                 17.109086
# min                    12.000000                 19.000000
# 25%                    56.000000                 61.500000
# 50%                    69.000000                 75.000000
# 75%                    82.000000                 85.000000
# max                    99.000000                 97.000000
#
#        Discrete Structure and Graph Theory  Data Structures  \
# count                           115.000000       115.000000
# mean                             63.121739        61.504348
# std                              13.316754        14.366368
# min                              11.000000        28.000000
# 25%                              53.000000        52.000000
# 50%                              62.000000        63.000000
# ...

# %%
df.head(5)
# Out:
#    Applied Mathematics - III  Applied Mathematics - IV  \
# 0                         94                        93
# 1                         90                        79
# 2                         19                        71
# 3                         71                        69
# 4                         64                        80
#
#    Discrete Structure and Graph Theory  Data Structures  \
# 0                                   82               70
# 1                                   64               80
# 2                                   48               40
# 3                                   62               54
# 4                                   62               43
#
#    Analysis Of Algorithm  Skill Based Lab (Java)  Skill Based Lab (Python)  \
# 0                     86                      47                        46
# 1                     70                      46                        37
# ...

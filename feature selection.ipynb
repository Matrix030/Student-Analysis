# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/final.csv', header=0)

# %%
df
# Out:
#     sex famsize  Medu  Fedu      Mjob      Fjob guardian  traveltime  \
# 0     F     GT3     4     4   at_home   teacher   mother           2
# 1     F     GT3     1     1   at_home     other   father           1
# 2     F     LE3     1     1   at_home     other   mother           1
# 3     F     GT3     4     2    health  services   mother           1
# 4     F     GT3     3     3     other     other   father           1
# ..   ..     ...   ...   ...       ...       ...      ...         ...
# 644   F     GT3     2     3  services     other   mother           1
# 645   F     LE3     3     1   teacher  services   mother           1
# 646   F     GT3     1     1     other     other   mother           2
# 647   M     LE3     3     1  services  services   mother           2
# 648   M     LE3     3     2  services     other   mother           3
#
#      studytime  failures extra_learning sports  internship higher  freetime  \
# ...

# %%
df.describe()
# Out:
#              Medu        Fedu  traveltime   studytime    failures  internship  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     2.514638    2.306626    1.568567    1.930663    0.221880    0.861325
# std      1.134552    1.099931    0.748660    0.829510    0.593235    0.773320
# min      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 25%      2.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 50%      2.000000    2.000000    1.000000    2.000000    0.000000    1.000000
# 75%      4.000000    3.000000    2.000000    2.000000    0.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    3.000000    2.000000
#
#          freetime       goout      health    absences         GPA
# count  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.180277    3.184900    3.536210    3.659476    7.385251
# std      1.051093    1.175766    1.446259    4.640759    2.390805
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="sex", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="famsize", data=df)
# Out:
# <AxesSubplot:xlabel='famsize', ylabel='count'>

# %%
sns.countplot(x="Mjob", data=df)
# Out:
# <AxesSubplot:xlabel='Mjob', ylabel='count'>

# %%
sns.countplot(x="Fjob", data=df)
# Out:
# <AxesSubplot:xlabel='Fjob', ylabel='count'>

# %%
sns.countplot(x="guardian", data=df)
# Out:
# <AxesSubplot:xlabel='guardian', ylabel='count'>

# %%
sns.countplot(x="extra_learning", data=df)
# Out:
# <AxesSubplot:xlabel='extra_learning', ylabel='count'>

# %%
sns.countplot(x="sports", data=df)
# Out:
# <AxesSubplot:xlabel='sports', ylabel='count'>

# %%
sns.countplot(x="higher", data=df)
# Out:
# <AxesSubplot:xlabel='higher', ylabel='count'>

# %%
sns.lineplot(df['GPA'],df['absences'])
# Out:
# c:\users\shardul\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GPA', ylabel='absences'>

# %%
sns.countplot(df['higher'],hue=df['sex'])
# Out:
# c:\users\shardul\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='higher', ylabel='count'>

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(12,5))
ax1.bar(df['Fedu'],df['GPA'],color='tomato')
ax1.set_xlabel('Father education')
ax1.set_ylabel('Grade')
ax2.bar(df['Medu'],df['GPA'],color='salmon')
ax2.set_xlabel('Mother education')
# Out:
# Text(0.5, 0, 'Mother education')

# %%
sns.jointplot(x = df['absences'], y = df['GPA'], data = df, kind = 'reg')

# %%
sns.jointplot(x = df['health'], y = df['GPA'], data = df, kind = 'reg')

# %%
sns.jointplot(x = df['health'], y = df['GPA'], data = df, kind = 'reg')

# %%
sns.jointplot(x = df['freetime'], y = df['GPA'], data = df, kind = 'reg')

# %%
sns.jointplot(x = df['internship'], y = df['GPA'], data = df, kind = 'reg')

# %%
sns.jointplot(x = df['failures'], y = df['GPA'], data = df, kind = 'reg')

# %%
df = pd.get_dummies(df)

# %%
df
# Out:
#      Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0       4     4           2          2         0           0         3      4
# 1       1     1           1          2         0           1         3      3
# 2       1     1           1          2         0           2         3      2
# 3       4     2           1          3         0           2         2      2
# 4       3     3           1          2         0           0         3      2
# ..    ...   ...         ...        ...       ...         ...       ...    ...
# 644     2     3           1          3         1           0         4      2
# 645     3     1           1          2         0           2         3      4
# 646     1     1           2          2         0           0         1      1
# 647     3     1           2          1         0           0         4      5
# 648     3     2           3          1         0           1         4      1
#
# ...

# %%
without_target = df.drop("GPA", axis = 1)

# %% [markdown]
# ##  1. Variance threshhold

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres = VarianceThreshold(threshold=0)
var_thres.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
len(df.columns[var_thres.get_support()])
# Out:
# 34

# %%
constant_columns = [column for column in df.columns
                    if column not in df.columns[var_thres.get_support()]]
print(len(constant_columns))
# Out:
# 0

# %%
for column in constant_columns:
    print(column)

# %%
df.drop(constant_columns, axis=1)
# Out:
#      Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0       4     4           2          2         0           0         3      4
# 1       1     1           1          2         0           1         3      3
# 2       1     1           1          2         0           2         3      2
# 3       4     2           1          3         0           2         2      2
# 4       3     3           1          2         0           0         3      2
# ..    ...   ...         ...        ...       ...         ...       ...    ...
# 644     2     3           1          3         1           0         4      2
# 645     3     1           1          2         0           2         3      4
# 646     1     1           2          2         0           0         1      1
# 647     3     1           2          1         0           0         4      5
# 648     3     2           3          1         0           1         4      1
#
# ...

# %%
df.drop_duplicates()
# Out:
#      Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0       4     4           2          2         0           0         3      4
# 1       1     1           1          2         0           1         3      3
# 2       1     1           1          2         0           2         3      2
# 3       4     2           1          3         0           2         2      2
# 4       3     3           1          2         0           0         3      2
# ..    ...   ...         ...        ...       ...         ...       ...    ...
# 644     2     3           1          3         1           0         4      2
# 645     3     1           1          2         0           2         3      4
# 646     1     1           2          2         0           0         1      1
# 647     3     1           2          1         0           0         4      5
# 648     3     2           3          1         0           1         4      1
#
# ...

# %% [markdown]
# ## 2. Correlation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
del df['sex_M']
del df['famsize_LE3']
del df['extra_learning_no']
del df['sports_no']
del df['higher_no']
# del df['guardian_mother']
# del df['Fjob_other']
# del df['Fedu']

# %%
df.head()
# Out:
#    Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0     4     4           2          2         0           0         3      4
# 1     1     1           1          2         0           1         3      3
# 2     1     1           1          2         0           2         3      2
# 3     4     2           1          3         0           2         2      2
# 4     3     3           1          2         0           0         3      2
#
#    health  absences  ...  Fjob_health  Fjob_other  Fjob_services  \
# 0       3         4  ...            0           0              0
# 1       3         2  ...            0           1              0
# 2       3         6  ...            0           1              0
# 3       5         0  ...            0           0              1
# 4       5         0  ...            0           1              0
#
#    Fjob_teacher  guardian_father  guardian_mother  guardian_other  \
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()
cor.to_csv("cor.csv")

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
            return col_corr

# %%
corr_features = correlation(df, 0.5)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'Fedu'}

# %%
df.describe()
# Out:
#              Medu        Fedu  traveltime   studytime    failures  internship  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     2.514638    2.306626    1.568567    1.930663    0.221880    0.861325
# std      1.134552    1.099931    0.748660    0.829510    0.593235    0.773320
# min      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 25%      2.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 50%      2.000000    2.000000    1.000000    2.000000    0.000000    1.000000
# 75%      4.000000    3.000000    2.000000    2.000000    0.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    3.000000    2.000000
#
#          freetime       goout      health    absences  ...  Fjob_health  \
# count  649.000000  649.000000  649.000000  649.000000  ...   649.000000
# mean     3.180277    3.184900    3.536210    3.659476  ...     0.035439
# ...

# %% [markdown]
# ## splitting dataset

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0     4     4           2          2         0           0         3      4
# 1     1     1           1          2         0           1         3      3
# 2     1     1           1          2         0           2         3      2
# 3     4     2           1          3         0           2         2      2
# 4     3     3           1          2         0           0         3      2
#
#    health  absences  ...  Fjob_health  Fjob_other  Fjob_services  \
# 0       3         4  ...            0           0              0
# 1       3         2  ...            0           1              0
# 2       3         6  ...            0           1              0
# 3       5         0  ...            0           0              1
# 4       5         0  ...            0           1              0
#
#    Fjob_teacher  guardian_father  guardian_mother  guardian_other  \
# ...

# %%
y = df['GPA'].values
y
# Out:
# array([ 9.08 ,  9.54 ,  0.   ,  7.54 ,  7.12 ,  8.5  ,  9.23 ,  8.92 ,
#         8.62 ,  0.   ,  8.08 ,  8.46 ,  8.46 ,  7.38 ,  7.73 ,  6.81 ,
#         5.96 ,  7.85 ,  8.5  ,  7.85 ,  6.5  ,  6.92 ,  8.62 ,  7.5  ,
#         0.   ,  6.23 ,  7.42 ,  0.   ,  8.54 ,  8.42 ,  8.   ,  6.77 ,
#         9.08 ,  0.   ,  7.62 ,  9.38 ,  7.69 ,  7.27 ,  0.   ,  6.65 ,
#         9.23 ,  7.23 ,  7.54 ,  7.54 ,  6.96 ,  0.   ,  9.23 ,  7.46 ,
#         6.08 ,  7.08 ,  8.46 ,  0.   ,  6.15 ,  9.04 ,  6.15 ,  9.38 ,
#         6.5  ,  6.08 ,  8.31 ,  8.15 ,  8.77 ,  0.   ,  7.31 ,  6.96 ,
#         7.08 ,  9.54 ,  9.08 ,  8.92 ,  7.5  ,  6.46 ,  7.88 , 10.   ,
#         6.85 ,  7.81 ,  6.65 ,  8.92 ,  8.42 ,  8.62 ,  6.5  ,  7.96 ,
#         5.85 ,  9.23 ,  9.23 ,  7.08 ,  5.65 ,  5.85 ,  6.62 ,  8.58 ,
#         8.15 ,  6.96 ,  8.62 ,  7.31 ,  6.27 ,  8.62 ,  7.15 ,  7.88 ,
#         5.04 ,  8.92 ,  6.65 ,  0.   ,  6.73 ,  6.77 ,  7.58 ,  7.27 ,
# ...

# %%
xnew = df
del xnew['GPA']

# %%
xnew
# Out:
#      Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0       4     4           2          2         0           0         3      4
# 1       1     1           1          2         0           1         3      3
# 2       1     1           1          2         0           2         3      2
# 3       4     2           1          3         0           2         2      2
# 4       3     3           1          2         0           0         3      2
# ..    ...   ...         ...        ...       ...         ...       ...    ...
# 644     2     3           1          3         1           0         4      2
# 645     3     1           1          2         0           2         3      4
# 646     1     1           2          2         0           0         1      1
# 647     3     1           2          1         0           0         4      5
# 648     3     2           3          1         0           1         4      1
#
# ...

# %%
X = xnew.values

# %%
X.shape
# Out:
# (649, 28)

# %%
X = np.delete(X,9,axis=1)

# %%
X.shape
# Out:
# (649, 27)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)
# print("X_train : \n", X_train )
# print("X_test : \n", X_test )
# print("y_train : \n", y_train )
# print("y_test : \n", y_test )

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# -0.07930377346427453

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([6.90371518, 7.98625744, 7.08008095, 8.23405423, 8.11656735,
#        6.19652802, 6.75441435, 7.07490008, 6.2140997 , 7.2394326 ,
#        7.30216894, 7.61101171, 7.70346827, 7.17982795, 6.23908125,
#        7.13617432, 6.54959982, 7.31318141, 8.24896901, 8.46708555,
#        7.37042431, 6.89283726, 6.59699951, 6.67105157, 7.16443733,
#        7.22513201, 6.95724567, 7.62462491, 7.71745947, 7.53266794,
#        7.99155134, 7.77322753, 7.92630542, 8.02829091, 7.59499613,
#        5.98894234, 8.19652415, 6.78859361, 7.06116815, 6.32708837,
#        6.78761874, 8.30073168, 8.1483757 , 6.88334835, 7.2163862 ,
#        6.94574004, 7.07074972, 8.07354509, 6.99111516, 7.69768931,
#        7.1882154 , 6.99303886, 5.89793333, 6.85684202, 8.35960343,
#        8.15440315, 8.08578713, 7.99090732, 7.23756904, 6.16013035,
#        6.60513016, 8.17840995, 6.94247253, 7.80602849, 7.32531632,
#        7.27599208, 7.40116911, 7.48357591, 6.91412328, 7.383018  ,
# ...

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 6.9   8.58]
#  [ 7.99  7.35]
#  [ 7.08  8.37]
#  [ 8.23 10.  ]
#  [ 8.12  8.5 ]
#  [ 6.2   7.12]
#  [ 6.75  6.67]
#  [ 7.07  7.41]
#  [ 6.21  9.23]
#  [ 7.24  5.85]
#  [ 7.3   7.96]
#  [ 7.61  6.88]
#  [ 7.7   9.3 ]
#  [ 7.18  7.67]
#  [ 6.24  0.  ]
#  [ 7.14  6.07]
#  [ 6.55  9.3 ]
#  [ 7.31  8.23]
#  [ 8.25  9.15]
#  [ 8.47  8.73]
#  [ 7.37  7.08]
#  [ 6.89  7.93]
#  [ 6.6   6.3 ]
#  [ 6.67  7.37]
#  [ 7.16  7.27]
#  [ 7.23  8.77]
#  [ 6.96  0.  ]
#  [ 7.62  9.96]
#  [ 7.72  8.67]
#  [ 7.53  6.48]
#  [ 7.99  8.46]
#  [ 7.77  7.42]
#  [ 7.93  6.58]
#  [ 8.03  9.14]
#  [ 7.59  6.67]
#  [ 5.99 10.  ]
#  [ 8.2   7.27]
#  [ 6.79  8.92]
#  [ 7.06  8.88]
#  [ 6.33  0.  ]
#  [ 6.79  8.31]
#  [ 8.3   8.69]
#  [ 8.15  8.73]
#  [ 6.88  6.59]
#  [ 7.22  9.77]
#  [ 6.95  6.88]
#  [ 7.07  9.37]
#  [ 8.07  8.46]
#  [ 6.99  7.54]
#  [ 7.7   7.69]
#  [ 7.19  8.52]
#  [ 6.99  8.12]
#  [ 5.9   6.15]
#  [ 6.86  6.08]
#  [ 8.36  9.18]
#  [ 8.15  7.87]
#  [ 8.09  8.93]
#  [ 7.99  6.8 ]
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('G:/SEM 5/mini-project/test_data1.csv', header=0)

# %%
df
# Out:
#      Applied Mathematics - III  Applied Mathematics - IV  \
# 0                           94                        93
# 1                           90                        79
# 2                           19                        71
# 3                           71                        69
# 4                           64                        80
# ..                         ...                       ...
# 110                         39                        32
# 111                         30                        49
# 112                         55                        68
# 113                         31                        19
# 114                         47                        47
#
#      Discrete Structure and Graph Theory  Data Structures  \
# 0                                     82               70
# 1                                     64               80
# 2                                     48               40
# ...

# %%
del df['class']

# %%
df
# Out:
#      Applied Mathematics - III  Applied Mathematics - IV  \
# 0                           94                        93
# 1                           90                        79
# 2                           19                        71
# 3                           71                        69
# 4                           64                        80
# ..                         ...                       ...
# 110                         39                        32
# 111                         30                        49
# 112                         55                        68
# 113                         31                        19
# 114                         47                        47
#
#      Discrete Structure and Graph Theory  Data Structures  \
# 0                                     82               70
# 1                                     64               80
# 2                                     48               40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Applied Mathematics - III            115 non-null    int64
#  1   Applied Mathematics - IV             115 non-null    int64
#  2   Discrete Structure and Graph Theory  115 non-null    int64
#  3   Data Structures                      115 non-null    int64
#  4   Analysis Of Algorithm                115 non-null    int64
#  5   Skill Based Lab (Java)               115 non-null    int64
#  6   Skill Based Lab (Python)             115 non-null    int64
#  7   GPA_SEM_III                          115 non-null    float64
#  8   GPA_SEM_IV                           115 non-null    float64
#  9   avg_GPA                              115 non-null    float64
# dtypes: float64(3), int64(7)
# memory usage: 9.1 KB

# %%
#df.describe

# %% [markdown]
# ## Finding variable dependancies

# %%
df.corr()
# Out:
#                                      Applied Mathematics - III  \
# Applied Mathematics - III                             1.000000
# Applied Mathematics - IV                              0.783799
# Discrete Structure and Graph Theory                   0.677680
# Data Structures                                       0.660466
# Analysis Of Algorithm                                 0.687216
# Skill Based Lab (Java)                                0.027807
# Skill Based Lab (Python)                              0.262948
# GPA_SEM_III                                           0.695409
# GPA_SEM_IV                                            0.586120
# avg_GPA                                               0.720465
#
#                                      Applied Mathematics - IV  \
# Applied Mathematics - III                            0.783799
# Applied Mathematics - IV                             1.000000
# Discrete Structure and Graph Theory                  0.635623
# ...

# %%
del df['Skill Based Lab (Java)']
del df['Skill Based Lab (Python)']

# %%
df
# Out:
#      Applied Mathematics - III  Applied Mathematics - IV  \
# 0                           94                        93
# 1                           90                        79
# 2                           19                        71
# 3                           71                        69
# 4                           64                        80
# ..                         ...                       ...
# 110                         39                        32
# 111                         30                        49
# 112                         55                        68
# 113                         31                        19
# 114                         47                        47
#
#      Discrete Structure and Graph Theory  Data Structures  \
# 0                                     82               70
# 1                                     64               80
# 2                                     48               40
# ...

# %%
df.corr()
# Out:
#                                      Applied Mathematics - III  \
# Applied Mathematics - III                             1.000000
# Applied Mathematics - IV                              0.783799
# Discrete Structure and Graph Theory                   0.677680
# Data Structures                                       0.660466
# Analysis Of Algorithm                                 0.687216
# GPA_SEM_III                                           0.695409
# GPA_SEM_IV                                            0.586120
# avg_GPA                                               0.720465
#
#                                      Applied Mathematics - IV  \
# Applied Mathematics - III                            0.783799
# Applied Mathematics - IV                             1.000000
# Discrete Structure and Graph Theory                  0.635623
# Data Structures                                      0.606226
# Analysis Of Algorithm                                0.710886
# ...

# %% [markdown]
# ## After adding attendance

# %%
df = pd.read_csv('G:/SEM 5/mini-project/test_data3.csv', header=0)

# %%
df
# Out:
#      Applied Mathematics - III  Applied Mathematics - IV  \
# 0                           94                        93
# 1                           90                        79
# 2                           19                        71
# 3                           71                        69
# 4                           64                        80
# ..                         ...                       ...
# 110                         39                        32
# 111                         30                        49
# 112                         55                        68
# 113                         31                        19
# 114                         47                        47
#
#      Discrete Structure and Graph Theory  Data Structures  \
# 0                                     82               70
# 1                                     64               80
# 2                                     48               40
# ...

# %%
df.corr()
# Out:
#                                      Applied Mathematics - III  \
# Applied Mathematics - III                             1.000000
# Applied Mathematics - IV                              0.783799
# Discrete Structure and Graph Theory                   0.677680
# Data Structures                                       0.660466
# Analysis Of Algorithm                                 0.687216
# Skill Based Lab (Java)                                0.027807
# Skill Based Lab (Python)                              0.262948
# Attendance                                            0.164965
# GPA_SEM_III                                           0.694712
# GPA_SEM_IV                                            0.586120
# avg_GPA                                               0.720465
#
#                                      Applied Mathematics - IV  \
# Applied Mathematics - III                            0.783799
# Applied Mathematics - IV                             1.000000
# ...

# %%
df.Attendance = df.Attendance.fillna(df.Attendance.mean())

# %%
df
# Out:
#      Applied Mathematics - III  Applied Mathematics - IV  \
# 0                           94                        93
# 1                           90                        79
# 2                           19                        71
# 3                           71                        69
# 4                           64                        80
# ..                         ...                       ...
# 110                         39                        32
# 111                         30                        49
# 112                         55                        68
# 113                         31                        19
# 114                         47                        47
#
#      Discrete Structure and Graph Theory  Data Structures  \
# 0                                     82               70
# 1                                     64               80
# 2                                     48               40
# ...

# %%
df.corr()
# Out:
#                                      Applied Mathematics - III  \
# Applied Mathematics - III                             1.000000
# Applied Mathematics - IV                              0.783799
# Discrete Structure and Graph Theory                   0.677680
# Data Structures                                       0.660466
# Analysis Of Algorithm                                 0.687216
# Skill Based Lab (Java)                                0.027807
# Skill Based Lab (Python)                              0.262948
# Attendance                                            0.144673
# GPA_SEM_III                                           0.694712
# GPA_SEM_IV                                            0.586120
# avg_GPA                                               0.720465
#
#                                      Applied Mathematics - IV  \
# Applied Mathematics - III                            0.783799
# Applied Mathematics - IV                             1.000000
# ...

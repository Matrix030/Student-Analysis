# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/all_marks1.csv', header=0)

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  DLDA.1    DIS  ECCF.1  DLDA_Lab.1  DS_Lab.1  OOPM_Lab.1  ECCF_Lab  \
# ...

# %%
del df['GPA_SEMIII']
del df['GPA_SEMIV']

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  AM_3.1  DS.1  DLDA.1    DIS  ECCF.1  DLDA_Lab.1  DS_Lab.1  \
# ...

# %%
data = df.dropna()

# %%
data
# Out:
#     AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  ...  \
# 0     94    70    82    71  70        47      46      48        94    93  ...
# 1     96    75    88    76  78        46      45      48        90    94  ...
# 2     26    53    65    46  60        46      45      45        90    58  ...
# 3     50    64    58    67  78        45      43      48        91    60  ...
# 4     66    70    59    52  46        40      42      45        90    60  ...
# ..   ...   ...   ...   ...  ..       ...     ...     ...       ...   ...  ...
# 90    90    58    89    67  70        43      43      43        85    86  ...
# 91    70    53    65    56  56        44      43      44        84    59  ...
# 92    62    35    60    52  40        33      35      39        84    71  ...
# 93    85    66    81    53  71        46      40      42        86    79  ...
# 94    74    52    67    46  56        44      42      42        84    71  ...
#
# ...

# %%
data.corr()
# Out:
#                    AM_3      DLDA      DSGT      ECCF        DS  DLDA_Lab  \
# AM_3           1.000000  0.634396  0.623876  0.608391  0.569826  0.251377
# DLDA           0.634396  1.000000  0.646108  0.691557  0.674292  0.500734
# DSGT           0.623876  0.646108  1.000000  0.629705  0.607921  0.313196
# ECCF           0.608391  0.691557  0.629705  1.000000  0.701049  0.359692
# DS             0.569826  0.674292  0.607921  0.701049  1.000000  0.414875
# DLDA_Lab       0.251377  0.500734  0.313196  0.359692  0.414875  1.000000
# BE_Lab         0.289895  0.467780  0.365435  0.508747  0.442568  0.562930
# DS_Lab         0.365442  0.491927  0.381049  0.446423  0.528761  0.600616
# OOPM_Lab       0.183664  0.420738  0.253044  0.302284  0.338011  0.528555
# AM_4           0.692358  0.467112  0.540604  0.511953  0.452915  0.193720
# AOA            0.586282  0.604270  0.575111  0.656082  0.556775  0.313568
# COA            0.563470  0.574350  0.538628  0.640531  0.572157  0.353558
# ...

# %%
sb.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['OOPM'] = df['OOPM'].interpolate()
df['AM_3.1'] = df['AM_3.1'].interpolate()
df['DS.1'] = df['DS.1'].interpolate()
df['DLDA.1'] = df['DLDA.1'].interpolate()
df['DIS'] = df['DIS'].interpolate()
df['ECCF.1'] = df['ECCF.1'].interpolate()

df['DLDA_Lab.1'] = df['DLDA_Lab.1'].interpolate()
df['DS_Lab.1'] = df['DS_Lab.1'].interpolate()
df['OOPM_Lab.1'] = df['OOPM_Lab.1'].interpolate()
df['ECCF_Lab'] = df['ECCF_Lab'].interpolate()
df['AM_3_Tutorial'] = df['AM_3_Tutorial'].interpolate()

# %%
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  AM_3.1    DS.1  DLDA.1    DIS  ECCF.1  DLDA_Lab.1  DS_Lab.1  \
# ...

# %%
df1 = pd.read_csv('G:/SEM 5/mini-project/dataset/semIII.csv', header=0)

# %%
df1
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  \
# 0      94    70    82    71  70        47      46      48        94
# 1      96    75    88    76  78        46      45      48        90
# 2      26    53    65    46  60        46      45      45        90
# 3      50    64    58    67  78        45      43      48        91
# 4      66    70    59    52  46        40      42      45        90
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...
# 110    39    26    43    15  36        40      38      44        94
# 111    30    41    51    41  40        37      41      43        93
# 112    55    61    66    47  64        46      40      44        90
# 113    31    40    50    49  44        34      42      44        90
# 114    47    35    43    47  42        36      41      43        89
#
#      GPA_SEMIII  ...  AM_3.1  DS.1  DLDA.1    DIS  ECCF.1  DLDA_Lab.1  \
# 0          9.08  ...  48.840  72.5  66.667  74.00   73.33       85.70
# ...

# %%
df1.corr()
# Out:
#                    AM_3      DLDA      DSGT      ECCF        DS  DLDA_Lab  \
# AM_3           1.000000  0.689861  0.689926  0.655607  0.661423  0.382325
# DLDA           0.689861  1.000000  0.718893  0.728102  0.730977  0.561101
# DSGT           0.689926  0.718893  1.000000  0.671602  0.680205  0.440101
# ECCF           0.655607  0.728102  0.671602  1.000000  0.722418  0.395719
# DS             0.661423  0.730977  0.680205  0.722418  1.000000  0.493957
# DLDA_Lab       0.382325  0.561101  0.440101  0.395719  0.493957  1.000000
# BE_Lab         0.359677  0.511414  0.429717  0.543886  0.490165  0.541732
# DS_Lab         0.259125  0.384022  0.301030  0.345271  0.451443  0.434367
# OOPM_Lab       0.018388  0.256029  0.112270  0.168892  0.195811  0.361078
# GPA_SEMIII     0.694585  0.774440  0.662758  0.766875  0.734671  0.530754
# OOPM           0.015982  0.051379 -0.050284  0.094047 -0.032254  0.198590
# AM_3.1        -0.019081  0.091421  0.092702  0.178420  0.070864  0.177810
# ...

# %%
#data.to_csv('dhsghausodgjohasg.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset-new/all_data1.csv', header=0)

# %%
df
# Out:
#      AM_SE  AM_IA  DLDA_SE  DLDA_IA  DSGT_SE  DSGT_IA  ECCF_SE  ECCF_IA  \
# 0       77     17       52       18       62       20       53       18
# 1       77     19       57       18       68       20       58       18
# 2       18      8       42       11       47       18       34       12
# 3       38     12       52       12       40       18       54       13
# 4       55     11       57       13       46       13       42       10
# ..     ...    ...      ...      ...      ...      ...      ...      ...
# 345     32      8       41       10       33       13       37       14
# 346     32     10       40       12       43       16       32       11
# 347     32     15       32       15       32       11       38        9
# 348     21     11        9        4       10        8        2        6
# 349     12      4       20        3       32        8       26        8
#
#      DS_SE  DS_IA  DigitalSL_TW  DSL_OP  BE_TW  BE_OP  DataSL_TW  DSL_OP.1  \
# 0       53     17            24      23     24     22         24        24
# 1       60     18            23      23     23     22         24        24
# 2       44     16            23      23     23     22         21        24
# 3       60     18            23      22     21     22         24        24
# 4       32     14            20      20     21     21         23        22
# ..     ...    ...           ...     ...    ...    ...        ...       ...
# 345     37     14            18      13     23     22         21        16
# 346     32     14            19      14     20     19         19        21
# 347     32     10            23      17     18     20         22        22
# 348      2      7            15      17     19     17         21        11
# 349     11      5            22      17     19     18         18        12
#
#      OOPM_TW  OOPM_OP  GPA_SEMIII
# 0         48       46        9.08
# 1         44       46        9.54
# 2         42       48        0.00
# 3         45       46        7.54
# 4         42       48        7.12
# ..       ...      ...         ...
# 345       39       38        5.96
# 346       36       44        5.77
# 347       47       47        5.62
# 348       39       34        0.00
# 349       36       26        0.00
#
# [350 rows x 19 columns]

# %%
df.describe()
# Out:
#             AM_SE       AM_IA     DLDA_SE     DLDA_IA     DSGT_SE     DSGT_IA  \
# count  350.000000  350.000000  350.000000  350.000000  350.000000  350.000000
# mean    51.862857   13.222857   48.262857   12.305714   51.145714   15.362857
# std     25.527973    4.084571   15.784892    3.440151   14.217465    3.414497
# min      0.000000    0.000000    6.000000    3.000000    5.000000    5.000000
# 25%     36.000000   10.000000   35.250000   10.000000   40.000000   13.000000
# 50%     55.000000   13.000000   50.500000   12.000000   51.000000   16.000000
# 75%     66.000000   17.000000   61.000000   15.000000   61.000000   18.000000
# max    377.000000   20.000000   78.000000   20.000000   79.000000   20.000000
#
#           ECCF_SE     ECCF_IA       DS_SE       DS_IA  DigitalSL_TW  \
# count  350.000000  350.000000  350.000000  350.000000    350.000000
# mean    45.417143   12.525714   45.617143   14.791429     20.548571
# std     14.056079    3.385994   13.389118   10.424208      3.087397
# min      2.000000    3.000000    2.000000    4.000000     11.000000
# 25%     34.000000   10.000000   35.000000   12.000000     19.000000
# 50%     45.000000   12.000000   47.000000   15.000000     21.000000
# 75%     55.000000   15.000000   56.000000   17.000000     23.000000
# max     75.000000   20.000000   70.000000  199.000000     24.000000
#
#            DSL_OP       BE_TW       BE_OP   DataSL_TW    DSL_OP.1     OOPM_TW  \
# count  350.000000  350.000000  350.000000  350.000000  350.000000  350.000000
# mean    19.788571   20.408571   20.002857   21.528571   19.920000   42.391429
# std      2.787793    2.295239    2.603170    2.514835    3.726218    4.383276
# min     12.000000   13.000000    0.000000   12.000000    0.000000   25.000000
# 25%     18.250000   19.000000   19.000000   20.250000   18.000000   40.000000
# 50%     20.000000   20.000000   20.000000   22.000000   21.000000   43.000000
# 75%     22.000000   22.000000   22.000000   23.000000   23.000000   45.000000
# max     24.000000   24.000000   32.000000   24.000000   24.000000   49.000000
#
#           OOPM_OP  GPA_SEMIII
# count  350.000000  350.000000
# mean    42.714286    6.354457
# std      4.606408    3.355176
# min     26.000000    0.000000
# 25%     40.000000    5.850000
# 50%     44.000000    7.540000
# 75%     46.000000    8.620000
# max     49.000000   10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AM_SE         350 non-null    int64
#  1   AM_IA         350 non-null    int64
#  2   DLDA_SE       350 non-null    int64
#  3   DLDA_IA       350 non-null    int64
#  4   DSGT_SE       350 non-null    int64
#  5   DSGT_IA       350 non-null    int64
#  6   ECCF_SE       350 non-null    int64
#  7   ECCF_IA       350 non-null    int64
#  8   DS_SE         350 non-null    int64
#  9   DS_IA         350 non-null    int64
#  10  DigitalSL_TW  350 non-null    int64
#  11  DSL_OP        350 non-null    int64
#  12  BE_TW         350 non-null    int64
#  13  BE_OP         350 non-null    int64
#  14  DataSL_TW     350 non-null    int64
#  15  DSL_OP.1      350 non-null    int64
#  16  OOPM_TW       350 non-null    int64
#  17  OOPM_OP       350 non-null    int64
#  18  GPA_SEMIII    350 non-null    float64
# dtypes: float64(1), int64(18)
# memory usage: 52.1 KB

# %%
min_GPA = df['GPA_SEMIII'].quantile(0.1)
print(min_GPA)
# Out:
# 0.0

# %%
df1 = df[df["GPA_SEMIII"]>min_GPA]

# %%
df1
# Out:
#      AM_SE  AM_IA  DLDA_SE  DLDA_IA  DSGT_SE  DSGT_IA  ECCF_SE  ECCF_IA  \
# 0       77     17       52       18       62       20       53       18
# 1       77     19       57       18       68       20       58       18
# 3       38     12       52       12       40       18       54       13
# 4       55     11       57       13       46       13       42       10
# 5       55     13       51       16       57       19       59       16
# ..     ...    ...      ...      ...      ...      ...      ...      ...
# 339     32     12       32       10       32       11       33       10
# 342     34     10       32       10       32       10       32        9
# 345     32      8       41       10       33       13       37       14
# 346     32     10       40       12       43       16       32       11
# 347     32     15       32       15       32       11       38        9
#
#      DS_SE  DS_IA  DigitalSL_TW  DSL_OP  BE_TW  BE_OP  DataSL_TW  DSL_OP.1  \
# 0       53     17            24      23     24     22         24        24
# 1       60     18            23      23     23     22         24        24
# 3       60     18            23      22     21     22         24        24
# 4       32     14            20      20     21     21         23        22
# 5       61     17            21      20     22     22         23        20
# ..     ...    ...           ...     ...    ...    ...        ...       ...
# 339     34     10            16      14     18     20         14        17
# 342     32     13            15      14     18     17         14        16
# 345     37     14            18      13     23     22         21        16
# 346     32     14            19      14     20     19         19        21
# 347     32     10            23      17     18     20         22        22
#
#      OOPM_TW  OOPM_OP  GPA_SEMIII
# 0         48       46        9.08
# 1         44       46        9.54
# 3         45       46        7.54
# 4         42       48        7.12
# 5         44       46        8.50
# ..       ...      ...         ...
# 339       26       32        4.58
# 342       29       40        4.73
# 345       39       38        5.96
# 346       36       44        5.77
# 347       47       47        5.62
#
# [281 rows x 19 columns]

# %%
df1.describe()
# Out:
#             AM_SE       AM_IA     DLDA_SE     DLDA_IA     DSGT_SE     DSGT_IA  \
# count  281.000000  281.000000  281.000000  281.000000  281.000000  281.000000
# mean    56.644128   14.270463   52.925267   13.035587   55.007117   16.227758
# std     13.945610    3.510924   12.686527    3.092412   12.290238    2.860709
# min     24.000000    4.000000   21.000000    6.000000   27.000000    8.000000
# 25%     46.000000   11.000000   43.000000   11.000000   46.000000   14.000000
# 50%     59.000000   14.000000   55.000000   13.000000   55.000000   17.000000
# 75%     68.000000   17.000000   63.000000   15.000000   66.000000   19.000000
# max     80.000000   20.000000   78.000000   20.000000   79.000000   20.000000
#
#           ECCF_SE     ECCF_IA       DS_SE       DS_IA  DigitalSL_TW  \
# count  281.000000  281.000000  281.000000  281.000000    281.000000
# mean    49.209964   13.302491   49.487544   15.658363     21.149466
# std     11.633789    3.087584   11.007174   11.383133      2.539490
# min     25.000000    6.000000   14.000000    7.000000     11.000000
# 25%     40.000000   11.000000   41.000000   13.000000     20.000000
# 50%     50.000000   13.000000   50.000000   15.000000     22.000000
# 75%     58.000000   16.000000   58.000000   17.000000     23.000000
# max     75.000000   20.000000   70.000000  199.000000     24.000000
#
#            DSL_OP       BE_TW       BE_OP   DataSL_TW    DSL_OP.1     OOPM_TW  \
# count  281.000000  281.000000  281.000000  281.000000  281.000000  281.000000
# mean    20.419929   20.779359   20.416370   22.085409   20.590747   43.064057
# std      2.257091    2.087651    2.007383    1.992800    2.895770    3.800774
# min     12.000000   13.000000   12.000000   14.000000   10.000000   25.000000
# 25%     20.000000   20.000000   19.000000   21.000000   19.000000   41.000000
# 50%     21.000000   21.000000   21.000000   23.000000   21.000000   44.000000
# 75%     22.000000   22.000000   22.000000   24.000000   23.000000   46.000000
# max     24.000000   24.000000   32.000000   24.000000   24.000000   49.000000
#
#           OOPM_OP  GPA_SEMIII
# count  281.000000  281.000000
# mean    43.338078    7.914804
# std      4.038601    1.279592
# min     29.000000    4.580000
# 25%     41.000000    6.960000
# 50%     44.000000    7.960000
# 75%     46.000000    8.920000
# max     49.000000   10.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 281 entries, 0 to 347
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AM_SE         281 non-null    int64
#  1   AM_IA         281 non-null    int64
#  2   DLDA_SE       281 non-null    int64
#  3   DLDA_IA       281 non-null    int64
#  4   DSGT_SE       281 non-null    int64
#  5   DSGT_IA       281 non-null    int64
#  6   ECCF_SE       281 non-null    int64
#  7   ECCF_IA       281 non-null    int64
#  8   DS_SE         281 non-null    int64
#  9   DS_IA         281 non-null    int64
#  10  DigitalSL_TW  281 non-null    int64
#  11  DSL_OP        281 non-null    int64
#  12  BE_TW         281 non-null    int64
#  13  BE_OP         281 non-null    int64
#  14  DataSL_TW     281 non-null    int64
#  15  DSL_OP.1      281 non-null    int64
#  16  OOPM_TW       281 non-null    int64
#  17  OOPM_OP       281 non-null    int64
#  18  GPA_SEMIII    281 non-null    float64
# dtypes: float64(1), int64(18)
# memory usage: 43.9 KB

# %%
plt.figure(figsize=(15, 12))
cor = df1.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()
# cor.to_csv("cor.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
# y = df['GPA_SEMIII'].values
# y

# %%
# xnew = df
# del xnew['GPA_SEMIII']

# %%
# xnew.head()

# %%
# xnew.info()

# %%
# X = xnew.values

# %%
# X.shape

# %%
X = df[[
        'AM_SE',
        'AM_IA',
        'DLDA_SE',
        'DLDA_IA',
        'DSGT_SE',
        'DSGT_IA',
        'ECCF_SE',
        'ECCF_IA',
        'DS_SE',
#         'DS_IA',
        'DigitalSL_TW',
        'DSL_OP',
        'BE_TW',
        'BE_OP',
        'DataSL_TW',
#         'DSL_OP.1',
        'OOPM_TW',
        'OOPM_OP'
       ]]

y=df['GPA_SEMIII']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.43678256092441103

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 9.82177148e+00,  4.83150820e+00,  7.05792611e+00,  2.38913779e+00,
#         1.09484177e+01,  2.22785175e+00,  5.37045487e+00,  7.93618671e+00,
#         8.84366656e+00,  1.16411770e+01,  2.78820325e+00,  6.28328034e+00,
#         4.19901927e+00,  8.53100897e+00,  4.29207041e+00,  8.54814033e+00,
#         7.11033795e+00,  9.83339105e+00,  3.19042909e+00,  1.04259512e+01,
#         1.06445801e+01,  4.41861791e+00,  5.91153598e+00,  6.23886183e+00,
#         9.14315161e+00,  6.81743763e+00,  5.74727862e+00,  5.92891158e+00,
#         8.76787658e+00,  8.00767669e+00,  6.78195976e+00,  8.92999637e+00,
#         4.42548715e+00,  1.90220961e+01,  9.97472434e+00,  5.34303502e+00,
#        -6.60480188e-01,  9.58618958e+00,  4.50944442e+00,  5.33782307e+00,
#         7.99217091e+00,  1.04108283e+01,  6.68751743e+00,  2.54461860e+00,
#         4.07865684e+00,  6.98650617e+00,  5.68165986e+00,  8.91001290e+00,
#         7.49089911e+00,  3.55327152e+00,  1.05651275e+01, -1.25903344e-02,
#         3.08447254e+00,  9.32027877e+00,  1.04901724e+01,  2.18494680e+00,
#         8.67635472e+00,  6.94900151e+00,  5.55486279e+00,  8.42186268e+00,
#         7.87137291e+00,  1.99545170e+00,  5.51875831e+00,  9.50548654e+00,
#         9.82310934e+00,  2.80378611e+00,  7.21004156e+00,  8.38374628e+00,
#         9.86425988e+00,  5.26885829e+00,  8.96095379e+00,  6.98466511e+00,
#         7.80006055e+00,  6.18643488e+00,  6.27483579e+00,  4.94931294e+00,
#         5.94702218e+00,  5.97055175e-01,  4.74994075e+00,  3.31334064e-01,
#         3.45986516e+00,  5.05533442e+00,  6.62199315e+00,  8.56153480e+00,
#         9.32155671e+00,  8.10057073e+00,  6.21342426e+00,  3.42913720e+00])

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f8393ac00dfb> in <module>
#       1 np.set_printoptions(precision=2)
# ----> 2 print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
#
# c:\users\shardul\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('G:/SEM 5/mini-project/code new/clustering/cluster-4.csv', header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AM4_SE     327 non-null    int64
#  1   AM4_IA     327 non-null    int64
#  2   AOA_SE     327 non-null    int64
#  3   AOA_IA     327 non-null    int64
#  4   COA_SE     327 non-null    int64
#  5   COA_IA     327 non-null    int64
#  6   CG_SE      327 non-null    int64
#  7   CG_IA      327 non-null    int64
#  8   OS_SE      327 non-null    int64
#  9   OS_IA      327 non-null    int64
#  10  AOA_TW     327 non-null    int64
#  11  AOA_OP     327 non-null    int64
#  12  CG_TW      327 non-null    int64
#  13  CG_OP      327 non-null    int64
#  14  PAL_TW     327 non-null    int64
#  15  PAL_OP     327 non-null    int64
#  16  OS_TW      327 non-null    int64
#  17  OS_OP      327 non-null    int64
#  18  OPST_TW    327 non-null    int64
#  19  OPST_OP    327 non-null    int64
#  20  GPA_SEM_4  327 non-null    float64
# dtypes: float64(1), int64(20)
# memory usage: 53.8 KB

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['GPA_SEM_4'].values
y
X = df.values
X = np.delete(X,20,axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor.score(X_test, y_test)
# Out:
# 0.7198114686929469

# %% [markdown]
# ## k-means

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# elbow plot
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(X)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
score = np.array(sse)
diff_scores = score / score[0]
diff_scores = np.diff(diff_scores)
n_clusters = np.argwhere(diff_scores < np.quantile(diff_scores, 0.9))[-1][0]
print(n_clusters)
# Out:
# 6

# %%
km = KMeans(n_clusters=6)
y_predicted = km.fit_predict(X)
y_predicted
# Out:
# array([0, 0, 5, 1, 5, 2, 0, 0, 2, 4, 1, 0, 2, 0, 0, 1, 2, 0, 0, 0, 1, 1,
#        0, 2, 2, 1, 0, 4, 0, 0, 2, 1, 0, 1, 4, 0, 2, 0, 4, 4, 0, 1, 0, 1,
#        0, 4, 0, 2, 5, 0, 0, 5, 2, 0, 4, 0, 5, 1, 2, 2, 2, 1, 2, 2, 1, 0,
#        0, 2, 2, 1, 1, 3, 1, 4, 2, 0, 0, 0, 4, 2, 5, 0, 0, 1, 1, 2, 1, 0,
#        0, 2, 0, 4, 2, 0, 2, 2, 1, 2, 1, 5, 1, 1, 2, 2, 5, 1, 1, 5, 1, 1,
#        5, 1, 1, 5, 1, 3, 3, 2, 2, 4, 0, 4, 4, 0, 4, 0, 2, 0, 0, 0, 0, 2,
#        0, 0, 3, 2, 2, 2, 2, 4, 2, 4, 3, 2, 3, 2, 3, 2, 1, 4, 0, 2, 0, 2,
#        4, 4, 5, 5, 2, 4, 2, 4, 2, 2, 4, 0, 1, 2, 2, 4, 4, 5, 4, 3, 2, 2,
#        2, 4, 1, 0, 0, 4, 3, 5, 2, 0, 2, 2, 4, 4, 1, 4, 4, 4, 5, 4, 2, 4,
#        2, 0, 2, 1, 1, 2, 2, 2, 5, 5, 5, 1, 0, 2, 5, 5, 4, 2, 5, 5, 1, 0,
#        1, 2, 5, 2, 5, 1, 3, 3, 0, 3, 3, 1, 2, 0, 1, 1, 1, 2, 1, 0, 3, 3,
#        3, 3, 3, 3, 0, 3, 1, 2, 1, 2, 2, 1, 0, 0, 3, 0, 3, 2, 3, 2, 3, 2,
#        0, 3, 2, 3, 1, 0, 1, 3, 0, 2, 2, 2, 5, 5, 0, 2, 0, 3, 3, 1, 3, 0,
#        2, 2, 3, 3, 0, 1, 3, 3, 3, 0, 0, 0, 3, 2, 3, 1, 1, 3, 3, 3, 1, 2,
#        1, 3, 0, 3, 3, 3, 3, 2, 3, 1, 2, 5, 1, 1, 1, 1, 1, 1, 5])

# %%
df['cluster']=y_predicted
df.head()
df.to_csv("cluster4.csv")

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
# df7 = df[df.cluster==6]
# df8 = df[df.cluster==7]
# df9 = df[df.cluster==8]
# df10 = df[df.cluster==9]
# df11 = df[df.cluster==10]
# df12 = df[df.cluster==11]
# df13 = df[df.cluster==12]
# df14 = df[df.cluster==13]
# df15 = df[df.cluster==14]
# df16 = df[df.cluster==15]
# df17 = df[df.cluster==16]

# %%
df1.to_csv("cluster4_0.csv")
df2.to_csv("cluster4_1.csv")
df3.to_csv("cluster4_2.csv")
df4.to_csv("cluster4_3.csv")
df5.to_csv("cluster4_4.csv")
df6.to_csv("cluster4_5.csv")
# df7.to_csv("cluster6.csv")
# df8.to_csv("cluster7.csv")
# df9.to_csv("cluster8.csv")
# df10.to_csv("cluster9.csv")
# df11.to_csv("cluster10.csv")
# df12.to_csv("cluster11.csv")
# df13.to_csv("cluster12.csv")
# df14.to_csv("cluster13.csv")
# df15.to_csv("cluster14.csv")
# df16.to_csv("cluster15.csv")
# df17.to_csv("cluster16.csv")

# %%
df1.describe()
# Out:
#           AM4_SE     AM4_IA     AOA_SE     AOA_IA     COA_SE     COA_IA  \
# count  72.000000  72.000000  72.000000  72.000000  72.000000  72.000000
# mean   69.111111  17.847222  65.500000  16.694444  60.625000  15.527778
# std     6.737650   2.560038   4.690416   2.268206   5.457744   2.772969
# min    49.000000   8.000000  54.000000  11.000000  43.000000   9.000000
# 25%    64.000000  17.000000  62.000000  15.000000  58.000000  13.750000
# 50%    71.000000  19.000000  66.000000  17.000000  62.000000  16.000000
# 75%    74.250000  20.000000  69.000000  18.000000  64.000000  18.000000
# max    80.000000  20.000000  75.000000  20.000000  72.000000  20.000000
#
#            CG_SE      CG_IA      OS_SE      OS_IA  ...      CG_TW      CG_OP  \
# count  72.000000  72.000000  72.000000  72.000000  ...  72.000000  72.000000
# mean   60.833333  16.708333  57.500000  16.055556  ...  20.777778  20.055556
# std     4.421459   2.536702   5.941025   3.175118  ...   2.163866   2.102238
# min    47.000000  10.000000  43.000000   8.000000  ...  14.000000  15.000000
# 25%    59.000000  16.000000  54.000000  14.750000  ...  20.000000  18.000000
# 50%    61.000000  17.000000  58.000000  16.000000  ...  21.000000  20.000000
# 75%    64.000000  18.000000  61.250000  18.250000  ...  23.000000  22.000000
# max    69.000000  20.000000  69.000000  20.000000  ...  24.000000  24.000000
#
#           PAL_TW     PAL_OP      OS_TW      OS_OP    OPST_TW    OPST_OP  \
# count  72.000000  72.000000  72.000000  72.000000  72.000000  72.000000
# mean   21.694444  19.625000  21.069444  20.555556  20.694444  20.805556
# std     1.700364   2.119244   2.196838   2.168201   1.820377   2.120582
# min    16.000000  15.000000  14.000000  14.000000  15.000000  14.000000
# 25%    21.000000  18.000000  20.000000  19.750000  19.000000  20.000000
# 50%    22.000000  20.000000  22.000000  21.000000  21.000000  21.000000
# 75%    23.000000  21.250000  22.250000  22.000000  22.000000  22.250000
# max    24.000000  23.000000  24.000000  24.000000  24.000000  24.000000
#
#        GPA_SEM_4  cluster
# count  72.000000     72.0
# mean    9.250972      0.0
# max    24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
#
#        GPA_SEM_4  cluster
# count  46.000000     46.0
# mean    9.831522      3.0
# std     0.200920      0.0
# min     9.250000      3.0
# 25%     9.707500      3.0
# 50%     9.850000      3.0
# 75%    10.000000      3.0
# max    10.000000      3.0
#
# [8 rows x 22 columns]

# %%
df5.describe()
# Out:
#           AM4_SE     AM4_IA     AOA_SE     AOA_IA     COA_SE     COA_IA  \
# count  35.000000  35.000000  35.000000  35.000000  35.000000  35.000000
# mean   58.257143  15.114286  43.800000  12.142857  34.771429   9.485714
# std     8.819573   2.709150   6.461652   2.658426   7.738695   2.638754
# min    44.000000   8.000000  32.000000   7.000000  13.000000   4.000000
# 25%    51.000000  14.000000  39.000000  11.000000  32.000000   7.500000
# 50%    59.000000  15.000000  43.000000  12.000000  35.000000  10.000000
# 75%    66.500000  17.000000  49.000000  13.000000  40.000000  11.000000
# max    73.000000  19.000000  56.000000  19.000000  48.000000  16.000000
#
#            CG_SE      CG_IA      OS_SE      OS_IA  ...      CG_TW      CG_OP  \
# count  35.000000  35.000000  35.000000  35.000000  ...  35.000000  35.000000
# mean   44.342857  12.828571  46.600000  13.342857  ...  19.028571  19.571429
# std     6.453193   2.770493  10.555734   2.838215  ...   2.583724   2.132186
# min    32.000000   8.000000  20.000000   8.000000  ...  13.000000  15.000000
# 25%    39.500000  11.000000  40.500000  11.500000  ...  18.000000  18.000000
# 50%    46.000000  13.000000  49.000000  14.000000  ...  19.000000  20.000000
# 75%    49.000000  15.000000  53.500000  15.000000  ...  20.000000  21.000000
# max    54.000000  18.000000  67.000000  19.000000  ...  24.000000  23.000000
#
#           PAL_TW     PAL_OP      OS_TW      OS_OP    OPST_TW    OPST_OP  \
# count  35.000000  35.000000  35.000000  35.000000  35.000000  35.000000
# mean   19.085714  18.400000  19.285714  19.714286  18.342857  18.400000
# std     2.993831   2.032095   2.203893   1.948928   2.743365   2.912448
# min    12.000000  14.000000  14.000000  15.000000  12.000000  10.000000
# 25%    18.500000  18.000000  18.500000  19.000000  17.000000  16.500000
# 50%    19.000000  19.000000  20.000000  20.000000  18.000000  19.000000
# 75%    21.000000  19.000000  21.000000  21.000000  20.000000  20.500000
# max    23.000000  22.000000  23.000000  22.000000  24.000000  23.000000
#
#        GPA_SEM_4  cluster
# count  35.000000     35.0
# mean    6.305143      4.0
# std     2.374565      0.0
# min     0.000000      4.0
# 25%     6.400000      4.0
# 50%     7.040000      4.0
# 75%     7.530000      4.0
# max     8.220000      4.0
#
# [8 rows x 22 columns]

# %%
df6.describe()
# Out:
#           AM4_SE     AM4_IA     AOA_SE     AOA_IA     COA_SE     COA_IA  \
# count  29.000000  29.000000  29.000000  29.000000  29.000000  29.000000
# mean   32.103448  10.034483  39.172414  10.827586  31.724138   9.310345
# std     9.766359   3.610330   7.778491   1.891125   9.709703   2.752965
# min    13.000000   4.000000  18.000000   8.000000   9.000000   3.000000
# 25%    25.000000   8.000000  37.000000  10.000000  32.000000   8.000000
# 50%    34.000000  10.000000  40.000000  11.000000  32.000000   9.000000
# 75%    40.000000  12.000000  44.000000  13.000000  36.000000  11.000000
# max    45.000000  18.000000  54.000000  14.000000  52.000000  14.000000
#
#            CG_SE      CG_IA      OS_SE      OS_IA  ...      CG_TW      CG_OP  \
# count  29.000000  29.000000  29.000000  29.000000  ...  29.000000  29.000000
# mean   34.275862  10.448276  41.206897  13.000000  ...  18.275862  17.448276
# std     8.911856   2.292631   9.802985   2.841026  ...   2.403815   2.746247
# min     0.000000   5.000000   0.000000   8.000000  ...  12.000000  12.000000
# 25%    32.000000   9.000000  39.000000  11.000000  ...  17.000000  16.000000
# 50%    36.000000  11.000000  42.000000  13.000000  ...  19.000000  18.000000
# 75%    40.000000  12.000000  47.000000  14.000000  ...  20.000000  19.000000
# max    43.000000  14.000000  54.000000  19.000000  ...  23.000000  22.000000
#
#           PAL_TW     PAL_OP      OS_TW      OS_OP    OPST_TW    OPST_OP  \
# count  29.000000  29.000000  29.000000  29.000000  29.000000  29.000000
# mean   18.793103  17.344828  20.137931  19.172414  17.448276  15.965517
# std     1.915712   1.395807   2.231658   1.794216   4.355507   5.596445
# min    15.000000  14.000000  13.000000  15.000000   0.000000   0.000000
# 25%    17.000000  17.000000  19.000000  18.000000  17.000000  14.000000
# 50%    19.000000  18.000000  21.000000  19.000000  18.000000  18.000000
# 75%    20.000000  18.000000  22.000000  20.000000  20.000000  19.000000
# max    23.000000  19.000000  23.000000  22.000000  23.000000  22.000000
#
#        GPA_SEM_4  cluster
# count  29.000000     29.0
# mean    2.917586      5.0
# std     3.077892      0.0
# min     0.000000      5.0
# 25%     0.000000      5.0
# 50%     0.000000      5.0
# 75%     6.000000      5.0
# max     6.460000      5.0
#
# [8 rows x 22 columns]

# %%
# cluster1=df.loc[df['cluster'] == 0]
# cluster2=df.loc[df['cluster'] == 1]
# cluster3=df.loc[df['cluster'] == 2]
# cluster4=df.loc[df['cluster'] == 3]
# cluster5=df.loc[df['cluster'] == 4]
# cluster6=df.loc[df['cluster'] == 5]

# scatter1 = dict(
#     mode = "markers",
#     name = "Cluster 1",
#     type = "scatter3d",    
#     x = cluster1.as_matrix()[:,0], y = cluster1.as_matrix()[:,1], z = cluster1.as_matrix()[:,2],
#     marker = dict( size=2, color='green')
# )
# scatter2 = dict(
#     mode = "markers",
#     name = "Cluster 2",
#     type = "scatter3d",    
#     x = cluster2.as_matrix()[:,0], y = cluster2.as_matrix()[:,1], z = cluster2.as_matrix()[:,2],
#     marker = dict( size=2, color='blue')
# )
# scatter3 = dict(
#     mode = "markers",
#     name = "Cluster 3",
#     type = "scatter3d",    
#     x = cluster3.as_matrix()[:,0], y = cluster3.as_matrix()[:,1], z = cluster3.as_matrix()[:,2],
#     marker = dict( size=2, color='red')
# )

# cluster1 = dict(
#     alphahull = 5,
#     name = "Cluster 1",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster1.as_matrix()[:,0], y = cluster1.as_matrix()[:,1], z = cluster1.as_matrix()[:,2],
#     color='green', showscale = True
# )
# cluster2 = dict(
#     alphahull = 5,
#     name = "Cluster 2",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster2.as_matrix()[:,0], y = cluster2.as_matrix()[:,1], z = cluster2.as_matrix()[:,2],
#     color='blue', showscale = True
# )
# cluster3 = dict(
#     alphahull = 5,
#     name = "Cluster 3",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster3.as_matrix()[:,0], y = cluster3.as_matrix()[:,1], z = cluster3.as_matrix()[:,2],
#     color='red', showscale = True
# )
# cluster4 = dict(
#     alphahull = 5,
#     name = "Cluster 4",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster1.as_matrix()[:,0], y = cluster1.as_matrix()[:,1], z = cluster1.as_matrix()[:,2],
#     color='green', showscale = True
# )
# cluster5 = dict(
#     alphahull = 5,
#     name = "Cluster 5",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster2.as_matrix()[:,0], y = cluster2.as_matrix()[:,1], z = cluster2.as_matrix()[:,2],
#     color='blue', showscale = True
# )
# cluster6 = dict(
#     alphahull = 5,
#     name = "Cluster 6",
#     opacity = .1,
#     type = "mesh3d",    
#     x = cluster3.as_matrix()[:,0], y = cluster3.as_matrix()[:,1], z = cluster3.as_matrix()[:,2],
#     color='red', showscale = True
# )
# layout = dict(
#     title = 'Interactive Cluster Shapes in 3D',
#     scene = dict(
#         xaxis = dict( zeroline=True ),
#         yaxis = dict( zeroline=True ),
#         zaxis = dict( zeroline=True ),
#     )
# )
# fig = dict( data=[scatter1, scatter2, scatter3, cluster1, cluster2, cluster3], layout=layout )
# # Use py.iplot() for IPython notebook
# plotly.offline.iplot(fig, filename='mesh3d_sample')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b18c4441aa9d> in <module>
#      10     name = "Cluster 1",
#      11     type = "scatter3d",
# ---> 12     x = cluster1.as_matrix()[:,0], y = cluster1.as_matrix()[:,1], z = cluster1.as_matrix()[:,2],
#      13     marker = dict( size=2, color='green')
#      14 )
#
# c:\users\shardul\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'as_matrix'

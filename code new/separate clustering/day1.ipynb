# %% [markdown]
# ## making clusters

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset-new/All_Marks_with_GPA.csv', header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    AM_SE        327 non-null    int64
#  1   AM_IA         327 non-null    int64
#  2   DLDA_SE       327 non-null    int64
#  3   DLDA_IA       327 non-null    int64
#  4   DSGT_SE       327 non-null    int64
#  5   DSGT_IA       327 non-null    int64
#  6   ECCF_SE       327 non-null    int64
#  7   ECCF_IA       327 non-null    int64
#  8   DS_SE         327 non-null    int64
#  9   DS_IA         327 non-null    int64
#  10  DigitalSL_TW  327 non-null    int64
#  11  DSL_OP        327 non-null    int64
#  12  BE_TW         327 non-null    int64
#  13  BE_OP         327 non-null    int64
#  14  DataSL_TW     327 non-null    int64
#  15  DSL_OP.1      327 non-null    int64
#  16  OOPM_TW       327 non-null    int64
#  17  OOPM_OP       327 non-null    int64
# ...

# %%
df.head()
# Out:
#     AM_SE  AM_IA  DLDA_SE  DLDA_IA  DSGT_SE  DSGT_IA  ECCF_SE  ECCF_IA  DS_SE  \
# 0      77     17       52       18       62       20       53       18     53
# 1      77     19       57       18       68       20       58       18     60
# 2      18      8       42       11       47       18       34       12     44
# 3      38     12       52       12       40       18       54       13     60
# 4      55     11       57       13       46       13       42       10     32
#
#    DS_IA  ...  CG_TW  CG_OP  PAL_TW  PAL_OP  OS_TW  OS_OP  OPST_TW  OPST_OP  \
# 0     17  ...     24     22      23      22     24     24       23       23
# 1     18  ...     23     23      21      22     23     24       24       23
# 2     16  ...     23     21      20      18     23     21       23       19
# 3     18  ...     23     21      24      18     23     23       24       22
# 4     14  ...     21     18      22      17     21     19       22       18
#
#     GPA  GPA_SEM_4
# 0  9.08       9.56
# ...

# %%
df.corr()
# Out:
#                  AM_SE     AM_IA   DLDA_SE   DLDA_IA   DSGT_SE   DSGT_IA  \
#  AM_SE        1.000000  0.734786  0.663284  0.516449  0.615685  0.568473
# AM_IA         0.734786  1.000000  0.661649  0.565381  0.687640  0.539891
# DLDA_SE       0.663284  0.661649  1.000000  0.524664  0.734693  0.519369
# DLDA_IA       0.516449  0.565381  0.524664  1.000000  0.522590  0.617750
# DSGT_SE       0.615685  0.687640  0.734693  0.522590  1.000000  0.555698
# DSGT_IA       0.568473  0.539891  0.519369  0.617750  0.555698  1.000000
# ECCF_SE       0.575333  0.648774  0.699291  0.517646  0.656621  0.495936
# ECCF_IA       0.508664  0.561177  0.509111  0.604142  0.486897  0.519260
# DS_SE         0.640802  0.567187  0.655565  0.553775  0.619853  0.589876
# DS_IA         0.492557  0.532430  0.555571  0.580585  0.541646  0.607512
# DigitalSL_TW  0.467189  0.463784  0.394386  0.483815  0.371078  0.442877
# DSL_OP        0.468090  0.336376  0.394293  0.441995  0.339026  0.504351
# ...

# %%
abc = df.corr()
abc.to_csv("all_correlation.csv")

# %%
X = df.values

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=6)
y_predicted = km.fit_predict(X)
y_predicted
# Out:
# array([3, 3, 2, 0, 2, 3, 3, 3, 3, 0, 0, 3, 3, 0, 3, 0, 0, 3, 3, 3, 0, 0,
#        3, 0, 0, 2, 0, 0, 3, 3, 3, 0, 3, 2, 0, 3, 0, 0, 4, 0, 3, 0, 3, 0,
#        0, 4, 3, 0, 4, 5, 3, 4, 2, 3, 2, 3, 2, 2, 3, 3, 3, 2, 0, 0, 0, 1,
#        5, 3, 0, 0, 0, 1, 2, 0, 0, 3, 3, 3, 0, 5, 2, 3, 3, 0, 2, 0, 2, 3,
#        3, 0, 3, 0, 0, 3, 0, 5, 2, 3, 0, 4, 2, 0, 0, 0, 4, 2, 2, 4, 2, 2,
#        4, 2, 0, 4, 2, 1, 3, 5, 0, 2, 3, 4, 5, 1, 0, 3, 3, 3, 1, 1, 3, 5,
#        3, 3, 1, 5, 5, 5, 5, 2, 5, 5, 1, 3, 1, 3, 1, 3, 2, 2, 1, 3, 5, 5,
#        5, 0, 2, 2, 5, 0, 0, 4, 2, 5, 4, 5, 2, 5, 5, 2, 5, 4, 5, 1, 5, 5,
#        5, 0, 2, 1, 1, 0, 1, 4, 5, 1, 5, 0, 5, 4, 0, 2, 2, 2, 2, 0, 3, 2,
#        5, 1, 5, 2, 0, 5, 3, 0, 4, 4, 4, 4, 3, 2, 4, 4, 2, 0, 4, 4, 2, 1,
#        2, 5, 4, 2, 4, 2, 1, 1, 5, 3, 1, 2, 3, 3, 0, 0, 0, 5, 2, 1, 1, 1,
#        1, 1, 1, 1, 1, 1, 5, 5, 2, 5, 5, 2, 3, 1, 1, 3, 1, 5, 1, 5, 1, 0,
#        5, 5, 5, 1, 2, 3, 5, 1, 3, 0, 5, 3, 4, 4, 3, 5, 5, 1, 1, 0, 1, 1,
# ...

# %%
df['cluster']=y_predicted
df.head()
df.to_csv("cluster.csv")

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]

# %%
df1.to_csv("cluster0_6.csv")
df2.to_csv("cluster1_6.csv")
df3.to_csv("cluster2_6.csv")
df4.to_csv("cluster3_6.csv")
df5.to_csv("cluster4_6.csv")
df6.to_csv("cluster5_6.csv")

# %%
abc = df1.describe()
abc.to_csv("c0_describe.csv")

# %%
abc = df2.describe()
abc.to_csv("c1_describe.csv")

# %%
abc = df3.describe()
abc.to_csv("c2_describe.csv")

# %%
abc = df4.describe()
abc.to_csv("c3_describe.csv")

# %%
abc = df5.describe()
abc.to_csv("c4_describe.csv")

# %%
abc = df6.describe()
abc.to_csv("c5_describe.csv")

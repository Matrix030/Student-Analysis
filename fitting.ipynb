# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/final.csv', header=0)

# %%
df
# Out:
#     sex famsize  Medu  Fedu      Mjob      Fjob guardian  traveltime  \
# 0     F     GT3     4     4   at_home   teacher   mother           2
# 1     F     GT3     1     1   at_home     other   father           1
# 2     F     LE3     1     1   at_home     other   mother           1
# 3     F     GT3     4     2    health  services   mother           1
# 4     F     GT3     3     3     other     other   father           1
# ..   ..     ...   ...   ...       ...       ...      ...         ...
# 644   F     GT3     2     3  services     other   mother           1
# 645   F     LE3     3     1   teacher  services   mother           1
# 646   F     GT3     1     1     other     other   mother           2
# 647   M     LE3     3     1  services  services   mother           2
# 648   M     LE3     3     2  services     other   mother           3
#
#      studytime  failures extra_learning sports  internship higher  freetime  \
# ...

# %%
df = pd.get_dummies(df)

# %%
del df['sex_M']
del df['famsize_LE3']
del df['extra_learning_no']
del df['sports_no']
del df['higher_no']
# del df['guardian_mother']
# del df['Fjob_other']
# del df['Fedu']

# %%
df.head()
# Out:
#    Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0     4     4           2          2         0           0         3      4
# 1     1     1           1          2         0           1         3      3
# 2     1     1           1          2         0           2         3      2
# 3     4     2           1          3         0           2         2      2
# 4     3     3           1          2         0           0         3      2
#
#    health  absences  ...  Fjob_health  Fjob_other  Fjob_services  \
# 0       3         4  ...            0           0              0
# 1       3         2  ...            0           1              0
# 2       3         6  ...            0           1              0
# 3       5         0  ...            0           0              1
# 4       5         0  ...            0           1              0
#
#    Fjob_teacher  guardian_father  guardian_mother  guardian_other  \
# ...

# %%
df.describe()
# Out:
#              Medu        Fedu  traveltime   studytime    failures  internship  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     2.514638    2.306626    1.568567    1.930663    0.221880    0.861325
# std      1.134552    1.099931    0.748660    0.829510    0.593235    0.773320
# min      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 25%      2.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 50%      2.000000    2.000000    1.000000    2.000000    0.000000    1.000000
# 75%      4.000000    3.000000    2.000000    2.000000    0.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    3.000000    2.000000
#
#          freetime       goout      health    absences  ...  Fjob_health  \
# count  649.000000  649.000000  649.000000  649.000000  ...   649.000000
# mean     3.180277    3.184900    3.536210    3.659476  ...     0.035439
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medu                649 non-null    int64
#  1   Fedu                649 non-null    int64
#  2   traveltime          649 non-null    int64
#  3   studytime           649 non-null    int64
#  4   failures            649 non-null    int64
#  5   internship          649 non-null    int64
#  6   freetime            649 non-null    int64
#  7   goout               649 non-null    int64
#  8   health              649 non-null    int64
#  9   absences            649 non-null    int64
#  10  GPA                 649 non-null    float64
#  11  sex_F               649 non-null    uint8
#  12  famsize_GT3         649 non-null    uint8
#  13  Mjob_at_home        649 non-null    uint8
#  14  Mjob_health         649 non-null    uint8
#  15  Mjob_other          649 non-null    uint8
# ...

# %% [markdown]
# ## Splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['GPA'].values
y
X = df.values
X = np.delete(X,10,axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=0)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor.score(X_test, y_test)
# Out:
# -0.14758165158445036

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([6.69513765, 7.98747588, 6.97485105, 8.2195655 , 8.14754572,
#        6.12819604, 6.78842851, 7.1187982 , 5.46463351, 7.20249724,
#        7.40399653, 7.48979499, 7.96022581, 7.16441443, 5.96482662,
#        7.06248382, 6.09929524, 7.31780788, 8.53162471, 8.26147458,
#        7.3933427 , 6.86005915, 6.39779205, 6.46316012, 7.25029699,
#        7.38250745, 6.91700595, 7.72287637, 7.75185175, 7.66452676,
#        8.06945986, 8.02510629, 7.7764236 , 7.85452496, 7.70428042,
#        5.72737225, 8.22336341, 6.84036719, 7.12106407, 6.47959447,
#        6.76913366, 8.24077936, 8.40432152, 6.97520051, 7.2066736 ,
#        6.89196006, 7.3720039 , 7.99884593, 6.98431022, 8.01224631,
#        6.89851604, 6.83762185, 5.06389249, 6.75476191, 8.26331375,
#        8.31837988, 8.1761363 , 8.25574331, 7.04987532, 6.12752129,
#        6.62979871, 8.17668092, 7.05367668, 7.88181314, 7.30112939,
#        7.51546227, 7.4235649 , 7.70067209, 7.20677337, 7.26980642,
# ...

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 6.7   8.58]
#  [ 7.99  7.35]
#  [ 6.97  8.37]
#  [ 8.22 10.  ]
#  [ 8.15  8.5 ]
#  [ 6.13  7.12]
#  [ 6.79  6.67]
#  [ 7.12  7.41]
#  [ 5.46  9.23]
#  [ 7.2   5.85]
#  [ 7.4   7.96]
#  [ 7.49  6.88]
#  [ 7.96  9.3 ]
#  [ 7.16  7.67]
#  [ 5.96  0.  ]
#  [ 7.06  6.07]
#  [ 6.1   9.3 ]
#  [ 7.32  8.23]
#  [ 8.53  9.15]
#  [ 8.26  8.73]
#  [ 7.39  7.08]
#  [ 6.86  7.93]
#  [ 6.4   6.3 ]
#  [ 6.46  7.37]
#  [ 7.25  7.27]
#  [ 7.38  8.77]
#  [ 6.92  0.  ]
#  [ 7.72  9.96]
#  [ 7.75  8.67]
#  [ 7.66  6.48]
#  [ 8.07  8.46]
#  [ 8.03  7.42]
#  [ 7.78  6.58]
#  [ 7.85  9.14]
#  [ 7.7   6.67]
#  [ 5.73 10.  ]
#  [ 8.22  7.27]
#  [ 6.84  8.92]
#  [ 7.12  8.88]
#  [ 6.48  0.  ]
#  [ 6.77  8.31]
#  [ 8.24  8.69]
#  [ 8.4   8.73]
#  [ 6.98  6.59]
#  [ 7.21  9.77]
#  [ 6.89  6.88]
#  [ 7.37  9.37]
#  [ 8.    8.46]
#  [ 6.98  7.54]
#  [ 8.01  7.69]
#  [ 6.9   8.52]
#  [ 6.84  8.12]
#  [ 5.06  6.15]
#  [ 6.75  6.08]
#  [ 8.26  9.18]
#  [ 8.32  7.87]
#  [ 8.18  8.93]
#  [ 8.26  6.8 ]
# ...

# %% [markdown]
# ## Splitting 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medu                649 non-null    int64
#  1   Fedu                649 non-null    int64
#  2   traveltime          649 non-null    int64
#  3   studytime           649 non-null    int64
#  4   failures            649 non-null    int64
#  5   internship          649 non-null    int64
#  6   freetime            649 non-null    int64
#  7   goout               649 non-null    int64
#  8   health              649 non-null    int64
#  9   absences            649 non-null    int64
#  10  GPA                 649 non-null    float64
#  11  sex_F               649 non-null    uint8
#  12  famsize_GT3         649 non-null    uint8
#  13  Mjob_at_home        649 non-null    uint8
#  14  Mjob_health         649 non-null    uint8
#  15  Mjob_other          649 non-null    uint8
# ...

# %%
# X=df[['Medu',
#       'traveltime','studytime','failures','freetime','goout','absences',
#       'sex_F',
#       'Mjob_at_home','Mjob_other','Mjob_teacher',
#       'Fjob_at_home','Fjob_health','Fjob_services',
#       'guardian_father','guardian_other',
#       'extra_learning_yes',
#       'sports_yes']]

X = df[[
#         'Medu',
        'Fedu',
        'traveltime',
        'studytime',
        'failures',
        'internship',
        'freetime',
        'goout',
#         'health',
        'absences',
        'sex_F',
#         'famsize_GT3',
        'Mjob_at_home',
#         'Mjob_health',
        'Mjob_other',
#         'Mjob_services',
        'Mjob_teacher',
        'Fjob_at_home',
        'Fjob_health',
        'Fjob_other',
        'Fjob_services',
#         'Fjob_teacher',
        'guardian_father',
        'guardian_mother',
#         'guardian_other',
        'extra_learning_yes',
#         'sports_yes',
#         'higher_yes'
       ]]

y=df['GPA']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=101)

# %%
regressor1 = LinearRegression()
regressor1.fit(X_train, y_train)
regressor1.score(X_test, y_test)
# Out:
# 0.05674960956084629

# %%
# 'Medu'
# 'traveltime'
# 'studytime'
# 'failures'
# 'internship'
# 'freetime'
# 'goout'
# 'health'
# 'absences'
# 'sex_F'
# 'famsize_GT3'
# 'Mjob_at_home'
# 'Mjob_health'
# 'Mjob_other'
# 'Mjob_services'
# 'Mjob_teacher'
# 'Fjob_at_home'
# 'Fjob_health'
# 'Fjob_services'
# 'Fjob_teacher'
# 'guardian_father'
# 'guardian_other'
# 'extra_learning_yes'
# 'sports_yes'
# 'higher_yes'

# %%
df.corr()
abc = df.corr()
abc.to_csv("CSV.csv")

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20, 20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap="Blues")
plt.show()
cor.to_csv("cor.csv")

# %% [markdown]
# ## k means

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df
# Out:
#      Medu  Fedu  traveltime  studytime  failures  internship  freetime  goout  \
# 0       4     4           2          2         0           0         3      4
# 1       1     1           1          2         0           1         3      3
# 2       1     1           1          2         0           2         3      2
# 3       4     2           1          3         0           2         2      2
# 4       3     3           1          2         0           0         3      2
# ..    ...   ...         ...        ...       ...         ...       ...    ...
# 644     2     3           1          3         1           0         4      2
# 645     3     1           1          2         0           2         3      4
# 646     1     1           2          2         0           0         1      1
# 647     3     1           2          1         0           0         4      5
# 648     3     2           3          1         0           1         4      1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medu                649 non-null    int64
#  1   Fedu                649 non-null    int64
#  2   traveltime          649 non-null    int64
#  3   studytime           649 non-null    int64
#  4   failures            649 non-null    int64
#  5   internship          649 non-null    int64
#  6   freetime            649 non-null    int64
#  7   goout               649 non-null    int64
#  8   health              649 non-null    int64
#  9   absences            649 non-null    int64
#  10  GPA                 649 non-null    float64
#  11  sex_F               649 non-null    uint8
#  12  famsize_GT3         649 non-null    uint8
#  13  Mjob_at_home        649 non-null    uint8
#  14  Mjob_health         649 non-null    uint8
#  15  Mjob_other          649 non-null    uint8
# ...

# %%
km = KMeans(n_clusters=17)
y_predicted = km.fit_predict(X)
y_predicted
# Out:
# array([ 0,  6, 14, 15,  2, 14,  3,  8,  2, 16,  8,  7, 16, 16,  9, 11,  1,
#         8,  3, 14, 15, 16,  9,  6,  8, 14,  1,  2,  8,  0, 16,  8, 16, 15,
#         5,  5, 16,  0,  8,  1,  4, 11, 16,  9,  4, 14, 11,  8,  5,  0,  7,
#        15,  0, 16, 16,  6, 15,  1,  9,  6, 16,  3,  9, 16, 16,  8, 16, 15,
#         2, 14,  7, 15,  6,  9,  8, 16, 15, 15,  9,  4,  2,  8,  5,  6,  6,
#         0, 11,  5, 14, 14,  8, 11,  9,  6,  6, 14, 14,  3,  0,  6, 13, 16,
#         8,  4, 16,  1, 14,  5, 11,  0,  0, 14, 13, 13,  5, 11,  0, 14,  4,
#         0, 15, 11,  8,  0,  3,  0, 16,  9, 11, 14,  2, 13,  1, 14,  6,  1,
#        14, 13,  8,  8,  0,  7,  6,  1,  1, 14,  3, 14,  3, 14, 12, 16,  5,
#         8,  5, 12,  9,  9,  8, 14, 11,  4,  3,  3, 11,  8, 11,  2, 16,  4,
#        11, 14,  3,  3,  1,  5,  6,  8,  3, 13,  3,  2,  2, 16,  0,  7, 16,
#        16,  3, 16,  3,  5,  1, 14,  5,  2, 16, 10,  1, 11,  9, 15,  1, 14,
# ...

# %%
df['cluster']=y_predicted
df.head()
df.to_csv("all_cluster.csv")

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
df7 = df[df.cluster==6]
df8 = df[df.cluster==7]
df9 = df[df.cluster==8]
df10 = df[df.cluster==9]
df11 = df[df.cluster==10]
df12 = df[df.cluster==11]
df13 = df[df.cluster==12]
df14 = df[df.cluster==13]
df15 = df[df.cluster==14]
df16 = df[df.cluster==15]
df17 = df[df.cluster==16]
# plt.scatter(df1.GPA,df1[['Medu','Fedu']],color='green')
# plt.scatter(df2.GPA,df2['Medu'],color='red')
# plt.scatter(df3.GPA,df3['Medu'],color='black')
# plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
# plt.xlabel('Age')
# plt.ylabel('GPA')
# plt.legend()

# %%
df1.info()
df2.info()
df3.info()
df4.info()
df5.info()
df6.info()
df7.info()
df8.info()
df9.info()
df10.info()
df11.info()
df12.info()
df13.info()
df14.info()
df15.info()
df16.info()
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 643
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medu                42 non-null     int64
#  1   Fedu                42 non-null     int64
#  2   traveltime          42 non-null     int64
#  3   studytime           42 non-null     int64
#  4   failures            42 non-null     int64
#  5   internship          42 non-null     int64
#  6   freetime            42 non-null     int64
#  7   goout               42 non-null     int64
#  8   health              42 non-null     int64
#  9   absences            42 non-null     int64
#  10  GPA                 42 non-null     float64
#  11  sex_F               42 non-null     uint8
#  12  famsize_GT3         42 non-null     uint8
#  13  Mjob_at_home        42 non-null     uint8
#  14  Mjob_health         42 non-null     uint8
#  15  Mjob_other          42 non-null     uint8
# ...

# %%
df1.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  42.000000  42.000000   42.000000  42.000000  42.000000   42.000000
# mean    3.452381   3.666667    1.619048   1.619048   0.190476    0.690476
# std     0.861150   0.611542    0.763573   0.696765   0.551632    0.715272
# min     1.000000   2.000000    1.000000   1.000000   0.000000    0.000000
# 25%     3.000000   3.250000    1.000000   1.000000   0.000000    0.000000
# 50%     4.000000   4.000000    1.000000   2.000000   0.000000    1.000000
# 75%     4.000000   4.000000    2.000000   2.000000   0.000000    1.000000
# max     4.000000   4.000000    3.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  42.000000  42.000000  42.000000  42.000000  ...   42.000000
# mean    3.928571   4.190476   3.547619   3.309524  ...    0.452381
# std     0.866528   0.740405   1.564895   1.023816  ...    0.503761
# ...

# %%
df2.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  35.000000  35.000000   35.000000  35.000000  35.000000   35.000000
# mean    2.371429   2.200000    1.428571   1.914286   0.200000    0.685714
# std     0.972738   1.051609    0.608069   0.817868   0.584103    0.795998
# min     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     2.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 50%     2.000000   2.000000    1.000000   2.000000   0.000000    0.000000
# 75%     3.000000   3.000000    2.000000   2.000000   0.000000    1.000000
# max     4.000000   4.000000    3.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  35.000000  35.000000  35.000000  35.000000  ...   35.000000
# mean    2.371429   2.628571   3.314286   8.771429  ...    0.514286
# std     0.770245   0.910259   1.586180   1.059570  ...    0.507093
# ...

# %%
df3.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  41.000000  41.000000   41.000000  41.000000  41.000000   41.000000
# mean    2.878049   2.609756    1.512195   1.560976   0.024390    0.951220
# std     1.076920   0.918642    0.553261   0.593666   0.156174    0.835201
# min     0.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     2.000000   2.000000    1.000000   1.000000   0.000000    0.000000
# 50%     3.000000   3.000000    1.000000   2.000000   0.000000    1.000000
# 75%     4.000000   3.000000    2.000000   2.000000   0.000000    2.000000
# max     4.000000   4.000000    3.000000   3.000000   1.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  41.000000  41.000000  41.000000  41.000000  ...   41.000000
# mean    1.707317   2.365854   3.463415   0.243902  ...    0.414634
# std     0.642024   0.829340   1.433485   0.623718  ...    0.498779
# ...

# %%
df4.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  56.000000  56.000000   56.000000  56.000000  56.000000   56.000000
# mean    1.839286   1.660714    1.785714   1.696429   0.375000    0.732143
# std     0.848031   0.694833    0.867898   0.736568   0.752269    0.774387
# min     1.000000   0.000000    1.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 50%     2.000000   2.000000    2.000000   2.000000   0.000000    1.000000
# 75%     2.000000   2.000000    2.000000   2.000000   0.250000    1.000000
# max     4.000000   3.000000    4.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  56.000000  56.000000  56.000000  56.000000  ...   56.000000
# mean    4.053571   4.660714   3.910714   0.214286  ...    0.696429
# std     0.818416   0.477752   1.404885   0.594346  ...    0.463961
# ...

# %%
df5.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  24.000000  24.000000   24.000000  24.000000  24.000000   24.000000
# mean    2.500000   2.833333    1.625000   1.708333   0.458333    1.166667
# std     0.978019   0.816497    0.824226   0.550033   0.721060    0.761387
# min     1.000000   2.000000    1.000000   1.000000   0.000000    0.000000
# 25%     2.000000   2.000000    1.000000   1.000000   0.000000    1.000000
# 50%     2.500000   3.000000    1.000000   2.000000   0.000000    1.000000
# 75%     3.000000   3.250000    2.000000   2.000000   1.000000    2.000000
# max     4.000000   4.000000    4.000000   3.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  24.000000  24.000000  24.000000  24.000000  ...   24.000000
# mean    2.958333   3.125000   3.916667  15.375000  ...    0.500000
# std     1.122078   1.329024   1.248187   1.408437  ...    0.510754
# ...

# %%
df6.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  48.000000  48.000000   48.000000  48.000000  48.000000   48.000000
# mean    1.979167   1.645833    1.562500   1.729167   0.333333    1.291667
# std     0.978266   0.699227    0.741082   0.706793   0.694456    0.742576
# min     0.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    1.000000   1.000000   0.000000    1.000000
# 50%     2.000000   2.000000    1.000000   2.000000   0.000000    1.000000
# 75%     3.000000   2.000000    2.000000   2.000000   0.000000    2.000000
# max     4.000000   3.000000    3.000000   3.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  48.000000  48.000000  48.000000  48.000000  ...   48.000000
# mean    3.541667   3.437500   3.687500   4.020833  ...    0.604167
# std     0.797825   0.896951   1.401462   0.437088  ...    0.494204
# ...

# %%
df7.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  46.000000  46.000000   46.000000  46.000000  46.000000   46.000000
# mean    2.130435   1.630435    1.608696   1.978261   0.260870    0.847826
# std     1.024341   0.678518    0.773973   0.745032   0.681005    0.787891
# min     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    1.000000   2.000000   0.000000    0.000000
# 50%     2.000000   2.000000    1.000000   2.000000   0.000000    1.000000
# 75%     3.000000   2.000000    2.000000   2.000000   0.000000    1.000000
# max     4.000000   3.000000    4.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  46.000000  46.000000  46.000000  46.000000  ...   46.000000
# mean    3.130435   3.673913   3.695652   1.956522  ...    0.782609
# std     0.718291   0.790340   1.396338   0.206185  ...    0.417029
# ...

# %%
df8.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  31.000000  31.000000   31.000000  31.000000  31.000000   31.000000
# mean    1.516129   1.096774    2.709677   2.032258   0.161290    0.709677
# std     0.625618   0.472923    0.739078   0.948116   0.373878    0.692510
# min     1.000000   0.000000    2.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    2.000000   1.000000   0.000000    0.000000
# 50%     1.000000   1.000000    3.000000   2.000000   0.000000    1.000000
# 75%     2.000000   1.000000    3.000000   2.500000   0.000000    1.000000
# max     3.000000   2.000000    4.000000   4.000000   1.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  31.000000  31.000000  31.000000  31.000000  ...   31.000000
# mean    2.516129   2.096774   3.193548   0.709677  ...    0.548387
# std     0.811212   0.700230   1.275914   0.937854  ...    0.505879
# ...

# %%
df9.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  42.000000  42.000000   42.000000  42.000000  42.000000   42.000000
# mean    3.119048   3.261905    1.404762   2.523810   0.095238    0.690476
# std     0.942296   0.766987    0.734499   0.833391   0.297102    0.643470
# min     1.000000   2.000000    1.000000   1.000000   0.000000    0.000000
# 25%     3.000000   3.000000    1.000000   2.000000   0.000000    0.000000
# 50%     3.000000   3.000000    1.000000   2.500000   0.000000    1.000000
# 75%     4.000000   4.000000    2.000000   3.000000   0.000000    1.000000
# max     4.000000   4.000000    4.000000   4.000000   1.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  42.000000  42.000000  42.000000  42.000000  ...   42.000000
# mean    2.809524   2.309524   3.738095   2.476190  ...    0.357143
# std     0.671296   0.780497   1.380341   0.833391  ...    0.484966
# ...

# %%
df10.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  44.000000  44.000000   44.000000  44.000000  44.000000   44.000000
# mean    1.840909   1.500000    1.295455   1.704545   0.363636    1.045455
# std     1.077102   0.549841    0.461522   0.593748   0.780307    0.776233
# min     0.000000   0.000000    1.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 50%     2.000000   2.000000    1.000000   2.000000   0.000000    1.000000
# 75%     2.250000   2.000000    2.000000   2.000000   0.000000    2.000000
# max     4.000000   2.000000    2.000000   3.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  44.000000  44.000000  44.000000  44.000000  ...   44.000000
# mean    3.750000   2.500000   3.409091   0.068182  ...    0.613636
# std     0.719334   0.731357   1.499119   0.333949  ...    0.492545
# ...

# %%
df11.describe()
# Out:
#            Medu      Fedu  traveltime  studytime  failures  internship  \
# count  2.000000  2.000000    2.000000   2.000000  2.000000    2.000000
# mean   3.500000  3.500000    1.500000   1.500000  0.500000    0.500000
# std    0.707107  0.707107    0.707107   0.707107  0.707107    0.707107
# min    3.000000  3.000000    1.000000   1.000000  0.000000    0.000000
# 25%    3.250000  3.250000    1.250000   1.250000  0.250000    0.250000
# 50%    3.500000  3.500000    1.500000   1.500000  0.500000    0.500000
# 75%    3.750000  3.750000    1.750000   1.750000  0.750000    0.750000
# max    4.000000  4.000000    2.000000   2.000000  1.000000    1.000000
#
#        freetime     goout    health   absences  ...  Fjob_other  \
# count  2.000000  2.000000  2.000000   2.000000  ...    2.000000
# mean   2.500000  3.500000  1.500000  31.000000  ...    0.500000
# std    0.707107  0.707107  0.707107   1.414214  ...    0.707107
# min    2.000000  3.000000  1.000000  30.000000  ...    0.000000
# ...

# %%
df12.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  47.000000  47.000000   47.000000  47.000000  47.000000   47.000000
# mean    2.765957   2.446809    1.702128   1.808511   0.234043    0.893617
# std     1.026026   1.099575    0.831836   0.924034   0.632894    0.786684
# min     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     2.000000   2.000000    1.000000   1.000000   0.000000    0.000000
# 50%     3.000000   2.000000    2.000000   2.000000   0.000000    1.000000
# 75%     4.000000   3.000000    2.000000   2.000000   0.000000    1.500000
# max     4.000000   4.000000    4.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  47.000000  47.000000  47.000000  47.000000  ...   47.000000
# mean    3.659574   4.404255   3.340426   7.148936  ...    0.595745
# std     0.891423   0.613599   1.478492   1.062784  ...    0.496053
# ...

# %%
df13.describe()
# Out:
#            Medu      Fedu  traveltime  studytime  failures  internship  \
# count  6.000000  6.000000    6.000000   6.000000   6.00000    6.000000
# mean   2.333333  1.666667    1.333333   1.333333   0.50000    1.000000
# std    1.032796  0.816497    0.516398   0.516398   0.83666    0.632456
# min    1.000000  1.000000    1.000000   1.000000   0.00000    0.000000
# 25%    2.000000  1.000000    1.000000   1.000000   0.00000    1.000000
# 50%    2.000000  1.500000    1.000000   1.000000   0.00000    1.000000
# 75%    2.750000  2.000000    1.750000   1.750000   0.75000    1.000000
# max    4.000000  3.000000    2.000000   2.000000   2.00000    2.000000
#
#        freetime     goout    health   absences  ...  Fjob_other  \
# count  6.000000  6.000000  6.000000   6.000000  ...    6.000000
# mean   3.666667  3.166667  3.166667  22.666667  ...    0.666667
# std    0.816497  1.169045  1.834848   1.966384  ...    0.516398
# min    3.000000  2.000000  1.000000  21.000000  ...    0.000000
# ...

# %%
df14.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  28.000000  28.000000   28.000000  28.000000  28.000000   28.000000
# mean    2.000000   1.750000    1.464286   1.750000   0.535714    0.678571
# std     0.902671   0.799305    0.637248   0.799305   0.961563    0.818923
# min     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 25%     1.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 50%     2.000000   2.000000    1.000000   2.000000   0.000000    0.000000
# 75%     2.250000   2.000000    2.000000   2.000000   1.000000    1.000000
# max     4.000000   4.000000    3.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  28.000000  28.000000  28.000000  28.000000  ...   28.000000
# mean    3.714286   3.964286   3.571429  10.928571  ...    0.714286
# std     1.083791   0.961563   1.549876   0.978607  ...    0.460044
# ...

# %%
df15.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  55.000000  55.000000   55.000000  55.000000  55.000000   55.000000
# mean    2.563636   2.272727    1.636364   1.963636   0.163636    0.909091
# std     1.150904   1.113129    0.778499   0.942095   0.536230    0.799832
# min     1.000000   0.000000    1.000000   1.000000   0.000000    0.000000
# 25%     2.000000   1.000000    1.000000   1.000000   0.000000    0.000000
# 50%     3.000000   2.000000    1.000000   2.000000   0.000000    1.000000
# 75%     4.000000   3.000000    2.000000   2.000000   0.000000    2.000000
# max     4.000000   4.000000    4.000000   4.000000   3.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  55.000000  55.000000  55.000000  55.000000  ...   55.000000
# mean    2.381818   2.054545   3.436364   5.145455  ...    0.672727
# std     0.952403   0.704961   1.437122   0.950987  ...    0.473542
# ...

# %%
df16.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  41.000000  41.000000   41.000000  41.000000  41.000000   41.000000
# mean    2.731707   2.000000    1.317073   2.926829   0.073171    0.609756
# std     1.162420   0.774597    0.471117   0.720772   0.345705    0.737497
# min     0.000000   0.000000    1.000000   2.000000   0.000000    0.000000
# 25%     2.000000   2.000000    1.000000   2.000000   0.000000    0.000000
# 50%     3.000000   2.000000    1.000000   3.000000   0.000000    0.000000
# 75%     4.000000   2.000000    2.000000   3.000000   0.000000    1.000000
# max     4.000000   4.000000    2.000000   4.000000   2.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  41.000000  41.000000  41.000000  41.000000  ...   41.000000
# mean    2.829268   2.487805   3.341463   0.024390  ...    0.634146
# std     0.667175   0.711405   1.371309   0.156174  ...    0.487652
# ...

# %%
df17.describe()
# Out:
#             Medu       Fedu  traveltime  studytime   failures  internship  \
# count  61.000000  61.000000   61.000000  61.000000  61.000000   61.000000
# mean    3.459016   3.590164    1.213115   2.081967   0.016393    0.934426
# std     0.886449   0.495885    0.412907   0.665710   0.128037    0.727298
# min     1.000000   3.000000    1.000000   1.000000   0.000000    0.000000
# 25%     3.000000   3.000000    1.000000   2.000000   0.000000    0.000000
# 50%     4.000000   4.000000    1.000000   2.000000   0.000000    1.000000
# 75%     4.000000   4.000000    1.000000   2.000000   0.000000    1.000000
# max     4.000000   4.000000    2.000000   4.000000   1.000000    2.000000
#
#         freetime      goout     health   absences  ...  Fjob_other  \
# count  61.000000  61.000000  61.000000  61.000000  ...   61.000000
# mean    3.655738   3.295082   3.557377   0.032787  ...    0.360656
# std     0.772124   0.954712   1.500273   0.179556  ...    0.484176
# ...

# %%
df1.to_csv("cluster0.csv")
df2.to_csv("cluster1.csv")
df3.to_csv("cluster2.csv")
df4.to_csv("cluster3.csv")
df5.to_csv("cluster4.csv")
df6.to_csv("cluster5.csv")
df7.to_csv("cluster6.csv")
df8.to_csv("cluster7.csv")
df9.to_csv("cluster8.csv")
df10.to_csv("cluster9.csv")
df11.to_csv("cluster10.csv")
df12.to_csv("cluster11.csv")
df13.to_csv("cluster12.csv")
df14.to_csv("cluster13.csv")
df15.to_csv("cluster14.csv")
df16.to_csv("cluster15.csv")
df17.to_csv("cluster16.csv")

# %%
# elbow plot
sse = []
k_rng = range(1,20)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(X)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
score = np.array(sse)
diff_scores = score / score[0]
diff_scores = np.diff(diff_scores)
n_clusters = np.argwhere(diff_scores < np.quantile(diff_scores, 0.9))[-1][0]
print(n_clusters)
# Out:
# 17

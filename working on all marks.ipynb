# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/all_marks1.csv', header=0)

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  DLDA_A  DIS_A  ECCF_A  DLDA_Lab_A  DS_Lab_A  OOPM_Lab_A  ECCF_Lab_A  \
# ...

# %%
abc = df.corr()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AM_3             115 non-null    int64
#  1   DLDA             115 non-null    int64
#  2   DSGT             115 non-null    int64
#  3   ECCF             115 non-null    int64
#  4   DS               115 non-null    int64
#  5   DLDA_Lab         115 non-null    int64
#  6   BE_Lab           115 non-null    int64
#  7   DS_Lab           115 non-null    int64
#  8   OOPM_Lab         115 non-null    int64
#  9   AM_4             115 non-null    int64
#  10  AOA              115 non-null    int64
#  11  COA              115 non-null    int64
#  12  CG               115 non-null    int64
#  13  OS               115 non-null    int64
#  14  AOA_Lab          115 non-null    int64
#  15  CG_Lab           115 non-null    int64
#  16  PA_Lab           115 non-null    int64
# ...

# %%
#abc.to_csv('corr.csv')

# %% [markdown]
# ## all marks with attendance

# %%
df = pd.read_csv('G:/SEM 5/mini-project/dataset/all_marks1.csv', header=0)

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  DLDA_A  DIS_A  ECCF_A  DLDA_Lab_A  DS_Lab_A  OOPM_Lab_A  ECCF_Lab_A  \
# ...

# %%
df['avg_GPA'] = (df.GPA_SEMIII +df.GPA_SEMIV)/2

# %%
df
# abc1 = df.corr()
# abc1.to_csv('all_corr.csv')
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  DIS_A  ECCF_A  DLDA_Lab_A  DS_Lab_A  OOPM_Lab_A  ECCF_Lab_A  \
# ...

# %%
del df['GPA_SEMIII']
del df['GPA_SEMIV']

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  DLDA_Lab  BE_Lab  DS_Lab  OOPM_Lab  AM_4  \
# 0      94    70    82    71  70        47      46      48        94    93
# 1      96    75    88    76  78        46      45      48        90    94
# 2      26    53    65    46  60        46      45      45        90    58
# 3      50    64    58    67  78        45      43      48        91    60
# 4      66    70    59    52  46        40      42      45        90    60
# ..    ...   ...   ...   ...  ..       ...     ...     ...       ...   ...
# 110    39    26    43    15  36        40      38      44        94    32
# 111    30    41    51    41  40        37      41      43        93    49
# 112    55    61    66    47  64        46      40      44        90    68
# 113    31    40    50    49  44        34      42      44        90    19
# 114    47    35    43    47  42        36      41      43        89    47
#
#      ...  DS_A  DLDA_A  DIS_A  ECCF_A  DLDA_Lab_A  DS_Lab_A  OOPM_Lab_A  \
# ...

# %%
df.corr()
# Out:
#                      AM_3      DLDA      DSGT      ECCF        DS  DLDA_Lab  \
# AM_3             1.000000  0.689861  0.689926  0.655607  0.661423  0.382325
# DLDA             0.689861  1.000000  0.718893  0.728102  0.730977  0.561101
# DSGT             0.689926  0.718893  1.000000  0.671602  0.680205  0.440101
# ECCF             0.655607  0.728102  0.671602  1.000000  0.722418  0.395719
# DS               0.661423  0.730977  0.680205  0.722418  1.000000  0.493957
# DLDA_Lab         0.382325  0.561101  0.440101  0.395719  0.493957  1.000000
# BE_Lab           0.359677  0.511414  0.429717  0.543886  0.490165  0.541732
# DS_Lab           0.259125  0.384022  0.301030  0.345271  0.451443  0.434367
# OOPM_Lab         0.018388  0.256029  0.112270  0.168892  0.195811  0.361078
# AM_4             0.783799  0.600990  0.650461  0.578161  0.602654  0.381427
# AOA              0.679099  0.681761  0.670405  0.702646  0.633373  0.407365
# ...

# %%
sb.heatmap(df.isnull())
#check null values
# Out:
# <AxesSubplot:>

# %%
df['OOPM_A'] = df['OOPM_A'].interpolate()
df['AM_3_A'] = df['AM_3_A'].interpolate()
df['DS_A'] = df['DS_A'].interpolate()
df['DLDA_A'] = df['DLDA_A'].interpolate()
df['DIS_A'] = df['DIS_A'].interpolate()
df['ECCF_A'] = df['ECCF_A'].interpolate()

df['DLDA_Lab_A'] = df['DLDA_Lab_A'].interpolate()
df['DS_Lab_A'] = df['DS_Lab_A'].interpolate()
df['OOPM_Lab_A'] = df['OOPM_Lab_A'].interpolate()
df['ECCF_Lab_A'] = df['ECCF_Lab_A'].interpolate()
df['AM_3_Tutorial_A'] = df['AM_3_Tutorial_A'].interpolate()

# %%
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AM_3             115 non-null    int64
#  1   DLDA             115 non-null    int64
#  2   DSGT             115 non-null    int64
#  3   ECCF             115 non-null    int64
#  4   DS               115 non-null    int64
#  5   DLDA_Lab         115 non-null    int64
#  6   BE_Lab           115 non-null    int64
#  7   DS_Lab           115 non-null    int64
#  8   OOPM_Lab         115 non-null    int64
#  9   AM_4             115 non-null    int64
#  10  AOA              115 non-null    int64
#  11  COA              115 non-null    int64
#  12  CG               115 non-null    int64
#  13  OS               115 non-null    int64
#  14  AOA_Lab          115 non-null    int64
#  15  CG_Lab           115 non-null    int64
#  16  PA_Lab           115 non-null    int64
# ...

# %%
del df['OOPM_A']
del df['AM_3_A']
del df['DS_A']
del df['DLDA_A']
del df['DIS_A']
del df['ECCF_A']
del df['DLDA_Lab_A']
del df['DS_Lab_A']
del df['OOPM_Lab_A']
del df['ECCF_Lab_A']
del df['AM_3_Tutorial_A']

del df['DLDA_Lab']
del df['BE_Lab']
del df['DS_Lab']
del df['OOPM_Lab']
del df['AOA_Lab']
del df['CG_Lab']
del df['PA_Lab']
del df['OS_Lab']
del df['OST_LAB']

# %%
df
# Out:
#      AM_3  DLDA  DSGT  ECCF  DS  AM_4  AOA  COA  CG  OS  avg_GPA
# 0      94    70    82    71  70    93   86   83  79  70    9.320
# 1      96    75    88    76  78    94   71   76  82  61    9.375
# 2      26    53    65    46  60    58   54   50  47  46    3.230
# 3      50    64    58    67  78    60   73   75  74  51    7.825
# 4      66    70    59    52  46    60   50   32  48  42    3.560
# ..    ...   ...   ...   ...  ..   ...  ...  ...  ..  ..      ...
# 110    39    26    43    15  36    32   46   25  46  53    0.000
# 111    30    41    51    41  40    49   56   63  59  60    3.425
# 112    55    61    66    47  64    68   66   63  64  50    7.300
# 113    31    40    50    49  44    19   47   64  56  59    0.000
# 114    47    35    43    47  42    47   55   68  62  67    3.465
#
# [115 rows x 11 columns]

# %% [markdown]
# ## Splitting dataset

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X = df.values

# %%
X
# Out:
# array([[94.   , 70.   , 82.   , ..., 79.   , 70.   ,  9.32 ],
#        [96.   , 75.   , 88.   , ..., 82.   , 61.   ,  9.375],
#        [26.   , 53.   , 65.   , ..., 47.   , 46.   ,  3.23 ],
#        ...,
#        [55.   , 61.   , 66.   , ..., 64.   , 50.   ,  7.3  ],
#        [31.   , 40.   , 50.   , ..., 56.   , 59.   ,  0.   ],
#        [47.   , 35.   , 43.   , ..., 62.   , 67.   ,  3.465]])

# %%
X = np.delete(X,10,axis=1)

# %%
X
# Out:
# array([[94., 70., 82., ..., 83., 79., 70.],
#        [96., 75., 88., ..., 76., 82., 61.],
#        [26., 53., 65., ..., 50., 47., 46.],
#        ...,
#        [55., 61., 66., ..., 63., 64., 50.],
#        [31., 40., 50., ..., 64., 56., 59.],
#        [47., 35., 43., ..., 68., 62., 67.]])

# %%
y = df['avg_GPA'].values

# %%
y
# Out:
# array([ 9.32 ,  9.375,  3.23 ,  7.825,  3.56 ,  8.695,  9.385,  9.11 ,
#         8.62 ,  3.65 ,  4.04 ,  8.635,  8.595,  8.005,  8.34 ,  7.09 ,
#         7.125,  8.685,  8.835,  8.74 ,  6.97 ,  7.25 ,  9.31 ,  8.195,
#         4.13 ,  6.98 ,  8.26 ,  3.4  ,  8.785,  8.98 ,  8.77 ,  7.145,
#         9.135,  3.77 ,  7.58 ,  9.285,  8.105,  8.08 ,  3.165,  7.215,
#         9.115,  7.28 ,  8.345,  7.47 ,  7.92 ,  0.   ,  9.3  ,  7.985,
#         3.04 ,  8.375,  8.88 ,  0.   ,  7.22 ,  9.37 ,  6.52 ,  9.555,
#         6.28 ,  6.755,  8.37 ,  8.295,  8.645,  3.5  ,  7.69 ,  7.48 ,
#         7.405,  9.655,  9.15 ,  9.14 ,  7.785,  7.02 ,  7.655, 10.   ,
#         7.52 ,  7.685,  7.12 ,  9.145,  8.69 ,  8.975,  7.17 ,  8.275,
#         2.925,  9.45 ,  9.3  ,  7.355,  6.175,  6.925,  6.865,  9.18 ,
#         8.5  ,  7.425,  8.775,  7.055,  7.265,  9.125,  7.55 ,  7.995,
#         6.075,  8.72 ,  6.935,  0.   ,  7.215,  7.385,  7.995,  7.635,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
print("X_train : \n", X_train )
print("X_test : \n", X_test )
print("y_train : \n", y_train )
print("y_test : \n", y_test )
# Out:
# X_train :
#  [[62. 35. 60. 52. 40. 71. 68. 71. 75. 76.]
#  [58. 15. 58. 43. 52. 70. 64. 57. 65. 59.]
#  [45. 20. 50. 40. 44. 75. 43. 33. 46. 31.]
#  [50. 64. 58. 67. 78. 60. 73. 75. 74. 51.]
#  [59. 46. 50. 41. 48. 62. 68. 28. 12. 11.]
#  [94. 87. 72. 76. 73. 95. 91. 76. 78. 75.]
#  [55. 46. 51. 44. 57. 62. 58. 48. 60. 60.]
#  [47. 35. 43. 47. 42. 47. 55. 68. 62. 67.]
#  [40. 40. 42. 44. 39. 42. 52. 71. 62. 79.]
#  [46. 51. 57. 61. 59. 56. 65. 68. 61. 78.]
#  [67. 61. 63. 65. 76. 69. 67. 75. 67. 77.]
#  [90. 58. 89. 67. 70. 86. 87. 74. 71. 73.]
#  [64. 62. 62. 55. 43. 80. 69. 58. 74. 74.]
#  [85. 47. 53. 17. 43. 87. 49. 50. 45. 40.]
#  [64. 70. 85. 65. 79. 78. 81. 74. 80. 66.]
#  [84. 67. 76. 64. 70. 81. 91. 71. 70. 62.]
#  [80. 68. 58. 68. 70. 89. 66. 66. 72. 77.]
#  [77. 51. 63. 56. 56. 70. 67. 70. 71. 73.]
#  [19. 46. 48. 27. 40. 71. 49. 62. 55. 58.]
#  [92. 68. 74. 57. 75. 85. 68. 83. 77. 78.]
#  [75. 64. 73. 66. 86. 92. 80. 75. 77. 79.]
# ...

# %% [markdown]
# ## linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.7851499720451494

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 6.18536999,  6.97408115,  8.93553198,  3.49656931,  9.88404914,
#         6.12454726,  5.67247003,  7.00009343,  4.6171079 ,  7.46535183,
#         9.10078641,  4.23040424,  9.25877726,  9.94913417,  6.00842164,
#         3.5772304 ,  7.14515858,  6.98793439,  9.42228617,  5.75369225,
#         5.98796806,  8.6233551 ,  8.7373322 ,  5.31710563, 10.95607123,
#         5.87610748,  2.23603139,  1.70821658,  8.38503841])

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 6.19  4.04]
#  [ 6.97  7.12]
#  [ 8.94  9.15]
#  [ 3.5   0.  ]
#  [ 9.88  9.11]
#  [ 6.12  7.17]
#  [ 5.67  7.05]
#  [ 7.    7.42]
#  [ 4.62  3.35]
#  [ 7.47  7.69]
#  [ 9.1   8.77]
#  [ 4.23  3.23]
#  [ 9.26  9.12]
#  [ 9.95  9.31]
#  [ 6.01  7.47]
#  [ 3.58  2.89]
#  [ 7.15  4.13]
#  [ 6.99  7.68]
#  [ 9.42  8.64]
#  [ 5.75  6.28]
#  [ 5.99  7.12]
#  [ 8.62  8.01]
#  [ 8.74  8.26]
#  [ 5.32  6.92]
#  [10.96 10.  ]
#  [ 5.88  6.87]
#  [ 2.24  0.  ]
#  [ 1.71  0.  ]
#  [ 8.39  8.62]]

# %%
# a = regressor.predict([[94,52,67,46,56,44,42,42,84,71,73,68,64,71,41,37,37,41,35,82.609,87,93.333,80,95.6,91.489,100,90,88.89,91.67,87.75
# ]])
# a

# %%
# abc1 = df.corr()

# %%
# abc1.to_csv('all_corr.csv')
